# %%
import findspark
findspark.init() # this must be executed before the below import

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql import SparkSession
from pyspark import SparkFiles

# %%
import ray
import time
import rtree
from rtree import index
import pandas as pd
import numpy as np
from numpy import genfromtxt
import threading
import pyarrow as pa
import pyarrow.parquet as pq

# %%
from NORAPartitionTree import *

# %%
conf = SparkConf().setAll([("spark.executor.memory", "24g"),("spark.driver.memory","24g"),
                           ("spark.memory.offHeap.enabled",True),("spark.memory.offHeap.size","16g"),
                          ("spark.driver.maxResultSize", "16g")])

sc = SparkContext(conf=conf)
sqlContext = SQLContext(sc)

# %%
def process_chunk_row(row, used_dims, partition_tree, pid_data_dict, count, k):
    if count[0] % 100000 == 0:
        print('proces',k,'has routed',count[0],'rows')
    count[0] += 1
    row_numpy = row.to_numpy()
    row_point = row_numpy[used_dims].tolist()
    pid = 0
    try:
        pid = partition_tree.get_pid_for_data_point(row_point)
    except:
        print(row_point)
    if pid in pid_data_dict:
        pid_data_dict[pid]+=[row_numpy.tolist()]
    else:
        pid_data_dict[pid]=[row_numpy.tolist()]

@ray.remote
def process_chunk(chunk, used_dims, partition_path, k, partition_tree):
    print("enter data routing process", k, '..')    
    pid_data_dict = {}
    count = [0]
    chunk.apply(lambda row: process_chunk_row(row, used_dims, partition_tree, pid_data_dict, count, k), axis=1)
    dict_id = ray.put(pid_data_dict)
    print("exit data routing process", k, ".")
    return dict_id

# %%
@ray.remote
def merge_epochs(parameters):
    #fs = pa.hdfs.connect()
    pids, epoch_count, hdfs_path, fs, merge_process = parameters
    for pid in pids:
        parquets = []
        for epoch in range(epoch_count):
            path = hdfs_path + "epoch_" + str(epoch) + '/partition_' + str(pid)+'.parquet'
            #print(path)
            try:
                par = pq.read_table(path)
                parquets.append(par)
            except:
                continue
        print("process", merge_process, "pid", pid, " len parquets (epochs):", len(parquets))
        if len(parquets) == 0:
            continue
        merged_parquet = pa.concat_tables(parquets)
        merge_path = hdfs_path + 'merged/partition_' + str(pid)+'.parquet'
        fw = fs.open_output_stream(merge_path)
        pq.write_table(merged_parquet, fw)
        fw.close()
    print('exit merge process', merge_process)

def merge_dict(base_dict, new_dict):
    for key, val in new_dict.items():
        if key in base_dict:
            base_dict[key] += val
        else:
            base_dict[key] = val
    new_dict.clear()

def dump_dict_2_hdfs_epoch(merged_dict, column_names, hdfs_path, fs, epoch):
    #print('= = = start dumping in main thread = = =')
    for pid, val in merged_dict.items():
        #print("writing to pid:",pid)
        path = hdfs_path + 'epoch_'+ str(epoch) +'/partition_' + str(pid) + '.parquet'
        pdf = pd.DataFrame(val, columns=column_names)
        adf = pa.Table.from_pandas(pdf)
        #fw = fs.open(path, 'wb')
        fw = fs.open_output_stream(path) # it seems the new version does not have the open function
        pq.write_table(adf, fw)
        fw.close()
    #print('= = = exit dumping = = =')

# %%
def batch_data_parallel(table_path, partition_path, chunk_size, used_dims, hdfs_path, num_dims, num_process, hdfs_private_ip):
    
    begin_time = time.time()
    
    ray.init(num_cpus=num_process)
    
    # column names for pandas dataframe
    cols = [i for i in range(num_dims)]
    col_names = ['_c'+str(i) for i in range(num_dims)]
    
    # pyarrow parquent append
    fs = pa.fs.HadoopFileSystem(hdfs_private_ip, port=9000, user='hdfs', replication=1)
    
    partition_tree = PartitionTree(len(used_dims))
    partition_tree.load_tree(partition_path)
    
    # chunks
    chunk_count = 0
    epoch_count = 0
    
    # collect object refs
    result_ids = []
    last_batch_ids = [] 
    first_loop = True
    
    for chunk in pd.read_table(table_path, delimiter='|', usecols=cols, names=col_names, chunksize=chunk_size):
        print('reading chunk: ', chunk_count)
        
        chunk_id = ray.put(chunk)
        result_id = process_chunk.remote(chunk_id, used_dims, partition_path, chunk_count, partition_tree)
        
        del chunk_id
        result_ids.append(result_id)
        del result_id
        
        # after all process allocated a chunk, process and dump the data
        if chunk_count % num_process == num_process - 1:
            
            if first_loop:
                first_loop = False
                last_batch_ids = result_ids.copy()
                result_ids.clear()
                chunk_count += 1
                continue
            else:
                print("= = = Process Dump For Chunk", chunk_count-2*num_process+1, "to", chunk_count-num_process, "= = =")
                base_dict = {}
                while len(last_batch_ids):
                    done_id, last_batch_ids = ray.wait(last_batch_ids)
                    dict_id = ray.get(done_id[0])
                    result_dict = ray.get(dict_id)
                    merge_dict(base_dict, result_dict)
                dump_dict_2_hdfs_epoch(base_dict, col_names, hdfs_path, fs, epoch_count) # consider whether we should use another process
                epoch_count += 1
                base_dict.clear()
                print("= = = Finish Dump For Chunk", chunk_count-2*num_process+1, "to", chunk_count-num_process, "= = =")
                last_batch_ids = result_ids.copy()
                result_ids.clear()
                
            current_time = time.time()
            time_elapsed = current_time - begin_time
            print("= = = TOTAL PROCESSED SO FAR:", (chunk_count-num_process+1) * chunk_size,"ROWS. TIME SPENT:", time_elapsed, "SECONDS = = =")
                
        chunk_count += 1
        
    # process the last few batches
    print("= = = Process Dump For Last Few Chunks = = =")
    base_dict = {}
    while len(last_batch_ids):
        done_id, last_batch_ids = ray.wait(last_batch_ids)
        dict_id = ray.get(done_id[0])
        result_dict = ray.get(dict_id)
        merge_dict(base_dict, result_dict)
    dump_dict_2_hdfs_epoch(base_dict, col_names, hdfs_path, fs, epoch_count)
    epoch_count += 1
    base_dict.clear()
    last_batch_ids.clear()

    base_dict = {}
    while len(result_ids):
        done_id, result_ids = ray.wait(result_ids)
        dict_id = ray.get(done_id[0])
        result_dict = ray.get(dict_id)
        merge_dict(base_dict, result_dict)
    result_ids.clear() # clear up the references
    dump_dict_2_hdfs_epoch(base_dict, col_names, hdfs_path, fs, epoch_count)
    epoch_count += 1
    base_dict.clear()
    result_ids.clear()
    
    
    # Merge all the epochs
    print("= = = Start Merging the Epochs = = =")
    leaves = partition_tree.get_leaves()
    pids = [leaf.nid for leaf in leaves]
    steps = len(pids) // num_process
    not_ready_ids = []
    for i in range(num_process):
        sub_pids = pids[i*steps:(i+1)*steps]
        if i == num_process - 1:
            sub_pids = pids[i*steps:]
        rid = merge_epochs.remote([sub_pids, epoch_count, hdfs_path, fs, i])
        not_ready_ids.append(rid)
        
    while len(not_ready_ids):
        ready_ids, not_ready_ids = ray.wait(not_ready_ids)
    
    ray.shutdown()
    
    finish_time = time.time()
    print('= = = = = TOTAL DATA ROUTING AND PERISITING TIME:', finish_time - begin_time, "= = = = =")

# %%
# = = = Configuration (UBDA Cloud Centos) = = =
scale_factor = 50
table_base_path = '/media/datadrive1/TPCH/dbgen/'
table_path = table_base_path + 'lineitem_' + str(scale_factor) + '.tbl'

num_process = 4
chunk_size = 2000000 
# 6M rows = about 1GB raw data

num_dims = 16
used_dims = [1,2,3,4]

# base path of HDFS
hdfs_private_ip = '192.168.6.62'
hdfs_base_path = 'hdfs://192.168.6.62:9000/user/cloudray/'

problem_type = 2

# nora_hdfs = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/'
# qdtree_hdfs = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/'
# kdtree_hdfs = hdfs_base_path + 'KDTree/prob' + str(problem_type) + '/'

nora_hdfs = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/"
qdtree_hdfs = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/"
kdtree_hdfs = hdfs_base_path + 'KDTree/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/"

# base path of Partition
partition_base_path = '/home/centos/PartitionLayout/'

# nora_partition = partition_base_path + 'prob' + str(problem_type) + '_nora'
# qdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_qdtree'
# kdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_kdtree'
nora_partition = partition_base_path + 'prob' + str(problem_type) + '_nora_scale' + str(scale_factor)
qdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_qdtree_scale' + str(scale_factor)
kdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_kdtree_scale'+ str(scale_factor)

# %%
# # if the merge phase failed, rerun with this one
# # Adjust epoch_count, num_process, partition_tree.load_tree(...), and qdtree_hdfs !!!

# ray.init(num_cpus=1)
# fs = pa.fs.HadoopFileSystem('192.168.6.62', port=9000, user='hdfs', replication=1)
    
# partition_tree = PartitionTree(len(used_dims))
# partition_tree.load_tree(qdtree_partition)

# epoch_count = 51

# leaves = partition_tree.get_leaves()
# pids = [leaf.nid for leaf in leaves]
# steps = len(pids) // num_process
# not_ready_ids = []
# for i in range(num_process):
#     sub_pids = pids[i*steps:(i+1)*steps]
#     if i == num_process - 1:
#         sub_pids = pids[i*steps:]
#     rid = merge_epochs.remote([sub_pids, epoch_count, qdtree_hdfs, fs, i])
#     not_ready_ids.append(rid)

# %%
# = = = Execution = = =
if __name__ == '__main__':
    batch_data_parallel(table_path, nora_partition, chunk_size, used_dims, nora_hdfs, num_dims, num_process, hdfs_private_ip)
    print('finish nora data routing..')
#     batch_data_parallel(table_path, qdtree_partition, chunk_size, used_dims, qdtree_hdfs, num_dims, num_process, hdfs_private_ip)
#     print('finish qdtree data routing..')
#     batch_data_parallel(table_path, kdtree_partition, chunk_size, used_dims, kdtree_hdfs, num_dims, num_process, hdfs_private_ip)
#     print('finish kdtree data routing..')
# Out:
# 2021-07-20 20:13:15,299	INFO services.py:1164 -- View the Ray dashboard at http://127.0.0.1:8265
# reading chunk:  0
# (pid=25582) enter data routing process 0 ..
# (pid=25582) proces 0 has routed 0 rows
# reading chunk:  1
# (pid=25582) proces 0 has routed 100000 rows
# (pid=25583) enter data routing process 1 ..
# (pid=25583) proces 1 has routed 0 rows
# reading chunk:  2
# (pid=25582) proces 0 has routed 200000 rows
# (pid=25583) proces 1 has routed 100000 rows
# (pid=25585) enter data routing process 2 ..
# (pid=25582) proces 0 has routed 300000 rows
# (pid=25585) proces 2 has routed 0 rows
# reading chunk:  3
# (pid=25583) proces 1 has routed 200000 rows
# (pid=25582) proces 0 has routed 400000 rows
# (pid=25585) proces 2 has routed 100000 rows
# (pid=25584) enter data routing process 3 ..
# (pid=25583) proces 1 has routed 300000 rows
# (pid=25584) proces 3 has routed 0 rows
# reading chunk:  4
# (pid=25582) proces 0 has routed 500000 rows
# (pid=25585) proces 2 has routed 200000 rows
# (pid=25583) proces 1 has routed 400000 rows
# (pid=25584) proces 3 has routed 100000 rows
# (pid=25585) proces 2 has routed 300000 rows
# (pid=25582) proces 0 has routed 600000 rows
# reading chunk:  5
# (pid=25583) proces 1 has routed 500000 rows
# (pid=25584) proces 3 has routed 200000 rows
# (pid=25582) proces 0 has routed 700000 rows
# (pid=25585) proces 2 has routed 400000 rows
# (pid=25584) proces 3 has routed 300000 rows
# (pid=25583) proces 1 has routed 600000 rows
# reading chunk:  6
# (pid=25585) proces 2 has routed 500000 rows
# (pid=25582) proces 0 has routed 800000 rows
# (pid=25583) proces 1 has routed 700000 rows
# (pid=25584) proces 3 has routed 400000 rows
# (pid=25582) proces 0 has routed 900000 rows
# (pid=25585) proces 2 has routed 600000 rows
# reading chunk:  7
# (pid=25583) proces 1 has routed 800000 rows
# (pid=25584) proces 3 has routed 500000 rows
# = = = Process Dump For Chunk 0 to 3 = = =
# (pid=25585) proces 2 has routed 700000 rows
# (pid=25582) proces 0 has routed 1000000 rows
# (pid=25583) proces 1 has routed 900000 rows
# (pid=25584) proces 3 has routed 600000 rows
# (pid=25582) proces 0 has routed 1100000 rows
# (pid=25585) proces 2 has routed 800000 rows
# (pid=25584) proces 3 has routed 700000 rows
# (pid=25583) proces 1 has routed 1000000 rows
# (pid=25582) proces 0 has routed 1200000 rows
# (pid=25585) proces 2 has routed 900000 rows
# (pid=25583) proces 1 has routed 1100000 rows
# (pid=25584) proces 3 has routed 800000 rows
# (pid=25585) proces 2 has routed 1000000 rows
# (pid=25582) proces 0 has routed 1300000 rows
# (pid=25583) proces 1 has routed 1200000 rows
# (pid=25584) proces 3 has routed 900000 rows
# (pid=25585) proces 2 has routed 1100000 rows
# (pid=25582) proces 0 has routed 1400000 rows
# (pid=25583) proces 1 has routed 1300000 rows
# (pid=25584) proces 3 has routed 1000000 rows
# (pid=25582) proces 0 has routed 1500000 rows
# (pid=25585) proces 2 has routed 1200000 rows
# (pid=25583) proces 1 has routed 1400000 rows
# (pid=25584) proces 3 has routed 1100000 rows
# (pid=25585) proces 2 has routed 1300000 rows
# (pid=25582) proces 0 has routed 1600000 rows
# (pid=25583) proces 1 has routed 1500000 rows
# (pid=25584) proces 3 has routed 1200000 rows
# (pid=25585) proces 2 has routed 1400000 rows
# (pid=25582) proces 0 has routed 1700000 rows
# (pid=25583) proces 1 has routed 1600000 rows
# (pid=25584) proces 3 has routed 1300000 rows
# (pid=25585) proces 2 has routed 1500000 rows
# (pid=25582) proces 0 has routed 1800000 rows
# (pid=25583) proces 1 has routed 1700000 rows
# (pid=25584) proces 3 has routed 1400000 rows
# (pid=25582) proces 0 has routed 1900000 rows
# (pid=25585) proces 2 has routed 1600000 rows
# (pid=25583) proces 1 has routed 1800000 rows
# (pid=25584) proces 3 has routed 1500000 rows
# (pid=25585) proces 2 has routed 1700000 rows
# (pid=25583) proces 1 has routed 1900000 rows
# (pid=25584) proces 3 has routed 1600000 rows
# (pid=25585) proces 2 has routed 1800000 rows
# (pid=25582) exit data routing process 0 .
# (pid=25584) proces 3 has routed 1700000 rows
# (pid=25582) enter data routing process 4 ..
# (pid=25585) proces 2 has routed 1900000 rows
# (pid=25582) proces 4 has routed 0 rows
# (pid=25584) proces 3 has routed 1800000 rows
# (pid=25583) exit data routing process 1 .
# (pid=25583) enter data routing process 5 ..
# (pid=25582) proces 4 has routed 100000 rows
# (pid=25584) proces 3 has routed 1900000 rows
# (pid=25583) proces 5 has routed 0 rows
# (pid=25585) exit data routing process 2 .
# (pid=25582) proces 4 has routed 200000 rows
# (pid=25583) proces 5 has routed 100000 rows
# (pid=25585) enter data routing process 6 ..
# (pid=25582) proces 4 has routed 300000 rows
# (pid=25585) proces 6 has routed 0 rows
# (pid=25583) proces 5 has routed 200000 rows
# (pid=25584) exit data routing process 3 .
# (pid=25582) proces 4 has routed 400000 rows
# (pid=25585) proces 6 has routed 100000 rows
# (pid=25584) enter data routing process 7 ..
# (pid=25583) proces 5 has routed 300000 rows
# (pid=25584) proces 7 has routed 0 rows
# (pid=25582) proces 4 has routed 500000 rows
# (pid=25585) proces 6 has routed 200000 rows
# (pid=25583) proces 5 has routed 400000 rows
# (pid=25584) proces 7 has routed 100000 rows
# (pid=25582) proces 4 has routed 600000 rows
# (pid=25585) proces 6 has routed 300000 rows
# (pid=25583) proces 5 has routed 500000 rows
# (pid=25584) proces 7 has routed 200000 rows
# (pid=25582) proces 4 has routed 700000 rows
# (pid=25585) proces 6 has routed 400000 rows
# (pid=25583) proces 5 has routed 600000 rows
# (pid=25584) proces 7 has routed 300000 rows
# (pid=25582) proces 4 has routed 800000 rows
# (pid=25585) proces 6 has routed 500000 rows
# (pid=25583) proces 5 has routed 700000 rows
# (pid=25584) proces 7 has routed 400000 rows
# (pid=25582) proces 4 has routed 900000 rows
# (pid=25585) proces 6 has routed 600000 rows
# (pid=25583) proces 5 has routed 800000 rows
# (pid=25584) proces 7 has routed 500000 rows
# (pid=25582) proces 4 has routed 1000000 rows
# (pid=25585) proces 6 has routed 700000 rows
# (pid=25583) proces 5 has routed 900000 rows
# (pid=25584) proces 7 has routed 600000 rows
# (pid=25582) proces 4 has routed 1100000 rows
# (pid=25585) proces 6 has routed 800000 rows
# (pid=25583) proces 5 has routed 1000000 rows
# (pid=25584) proces 7 has routed 700000 rows
# (pid=25582) proces 4 has routed 1200000 rows
# (pid=25585) proces 6 has routed 900000 rows
# (pid=25583) proces 5 has routed 1100000 rows
# (pid=25584) proces 7 has routed 800000 rows
# (pid=25582) proces 4 has routed 1300000 rows
# (pid=25585) proces 6 has routed 1000000 rows
# (pid=25583) proces 5 has routed 1200000 rows
# (pid=25584) proces 7 has routed 900000 rows
# (pid=25582) proces 4 has routed 1400000 rows
# = = = Finish Dump For Chunk 0 to 3(pid=25585) proces 6 has routed 1100000 rows
# (pid=25583) proces 5 has routed 1300000 rows
# (pid=25584) proces 7 has routed 1000000 rows
#  = = =
# = = = TOTAL PROCESSED SO FAR: 8000000 ROWS. TIME SPENT: 162.9341585636139 SECONDS = = =
# (pid=25582) proces 4 has routed 1500000 rows
# (pid=25585) proces 6 has routed 1200000 rows
# (pid=25583) proces 5 has routed 1400000 rows
# (pid=25584) proces 7 has routed 1100000 rows
# reading chunk:  8
# (pid=25582) proces 4 has routed 1600000 rows
# (pid=25585) proces 6 has routed 1300000 rows
# (pid=25583) proces 5 has routed 1500000 rows
# (pid=25584) proces 7 has routed 1200000 rows
# (pid=25582) proces 4 has routed 1700000 rows
# (pid=25585) proces 6 has routed 1400000 rows
# reading chunk:  9
# (pid=25583) proces 5 has routed 1600000 rows
# (pid=25584) proces 7 has routed 1300000 rows
# (pid=25582) proces 4 has routed 1800000 rows
# (pid=25583) proces 5 has routed 1700000 rows
# (pid=25585) proces 6 has routed 1500000 rows
# (pid=25584) proces 7 has routed 1400000 rows
# reading chunk:  10
# (pid=25582) proces 4 has routed 1900000 rows
# (pid=25583) proces 5 has routed 1800000 rows
# (pid=25585) proces 6 has routed 1600000 rows
# (pid=25584) proces 7 has routed 1500000 rows
# reading chunk:  11
# (pid=25585) proces 6 has routed 1700000 rows
# (pid=25583) proces 5 has routed 1900000 rows
# (pid=25584) proces 7 has routed 1600000 rows
# = = = Process Dump For Chunk 4 to 7 = = =
# (pid=25585) proces 6 has routed 1800000 rows
# (pid=25582) exit data routing process 4 .
# (pid=25584) proces 7 has routed 1700000 rows
# (pid=25582) enter data routing process 8 ..
# (pid=25582) proces 8 has routed 0 rows
# (pid=25584) proces 7 has routed 1800000 rows
# (pid=25585) proces 6 has routed 1900000 rows
# (pid=25583) exit data routing process 5 .
# (pid=25582) proces 8 has routed 100000 rows
# (pid=25583) enter data routing process 9 ..
# (pid=25584) proces 7 has routed 1900000 rows
# (pid=25583) proces 9 has routed 0 rows
# (pid=25582) proces 8 has routed 200000 rows
# (pid=25585) exit data routing process 6 .
# (pid=25583) proces 9 has routed 100000 rows
# (pid=25582) proces 8 has routed 300000 rows
# (pid=25585) enter data routing process 10 ..
# (pid=25583) proces 9 has routed 200000 rows
# (pid=25585) proces 10 has routed 0 rows
# (pid=25584) exit data routing process 7 .
# (pid=25582) proces 8 has routed 400000 rows
# (pid=25584) enter data routing process 11 ..
# (pid=25583) proces 9 has routed 300000 rows
# (pid=25585) proces 10 has routed 100000 rows
# (pid=25584) proces 11 has routed 0 rows
# (pid=25582) proces 8 has routed 500000 rows
# (pid=25583) proces 9 has routed 400000 rows
# (pid=25585) proces 10 has routed 200000 rows
# (pid=25584) proces 11 has routed 100000 rows
# (pid=25582) proces 8 has routed 600000 rows
# (pid=25585) proces 10 has routed 300000 rows
# (pid=25583) proces 9 has routed 500000 rows
# (pid=25584) proces 11 has routed 200000 rows
# (pid=25582) proces 8 has routed 700000 rows
# (pid=25585) proces 10 has routed 400000 rows
# (pid=25583) proces 9 has routed 600000 rows
# (pid=25584) proces 11 has routed 300000 rows
# (pid=25582) proces 8 has routed 800000 rows
# (pid=25583) proces 9 has routed 700000 rows
# (pid=25585) proces 10 has routed 500000 rows
# (pid=25584) proces 11 has routed 400000 rows
# (pid=25582) proces 8 has routed 900000 rows
# (pid=25583) proces 9 has routed 800000 rows
# (pid=25585) proces 10 has routed 600000 rows
# (pid=25584) proces 11 has routed 500000 rows
# (pid=25582) proces 8 has routed 1000000 rows
# (pid=25583) proces 9 has routed 900000 rows
# (pid=25585) proces 10 has routed 700000 rows
# (pid=25584) proces 11 has routed 600000 rows
# (pid=25582) proces 8 has routed 1100000 rows
# (pid=25585) proces 10 has routed 800000 rows
# (pid=25583) proces 9 has routed 1000000 rows
# (pid=25584) proces 11 has routed 700000 rows
# (pid=25582) proces 8 has routed 1200000 rows
# (pid=25585) proces 10 has routed 900000 rows
# (pid=25583) proces 9 has routed 1100000 rows
# (pid=25584) proces 11 has routed 800000 rows
# (pid=25582) proces 8 has routed 1300000 rows
# (pid=25583) proces 9 has routed 1200000 rows
# (pid=25585) proces 10 has routed 1000000 rows
# (pid=25584) proces 11 has routed 900000 rows
# (pid=25582) proces 8 has routed 1400000 rows
# (pid=25583) proces 9 has routed 1300000 rows= = = Finish Dump For Chunk 4 to 7 = = =
# (pid=25585) proces 10 has routed 1100000 rows
# (pid=25584) proces 11 has routed 1000000 rows
#
# = = = TOTAL PROCESSED SO FAR: 16000000 ROWS. TIME SPENT: 255.10945892333984 SECONDS = = =
# (pid=25582) proces 8 has routed 1500000 rows
# (pid=25583) proces 9 has routed 1400000 rows
# (pid=25585) proces 10 has routed 1200000 rows
# (pid=25584) proces 11 has routed 1100000 rows
# reading chunk:  12
# (pid=25582) proces 8 has routed 1600000 rows
# (pid=25583) proces 9 has routed 1500000 rows
# (pid=25584) proces 11 has routed 1200000 rows
# (pid=25585) proces 10 has routed 1300000 rows
# (pid=25582) proces 8 has routed 1700000 rows
# reading chunk:  13
# (pid=25583) proces 9 has routed 1600000 rows
# (pid=25585) proces 10 has routed 1400000 rows
# (pid=25584) proces 11 has routed 1300000 rows
# (pid=25582) proces 8 has routed 1800000 rows
# (pid=25585) proces 10 has routed 1500000 rows
# (pid=25583) proces 9 has routed 1700000 rows
# (pid=25584) proces 11 has routed 1400000 rows
# (pid=25582) proces 8 has routed 1900000 rows
# reading chunk:  14
# (pid=25583) proces 9 has routed 1800000 rows
# (pid=25584) proces 11 has routed 1500000 rows
# (pid=25585) proces 10 has routed 1600000 rows
# (pid=25583) proces 9 has routed 1900000 rows
# reading chunk:  15
# (pid=25585) proces 10 has routed 1700000 rows
# (pid=25584) proces 11 has routed 1600000 rows
# = = = Process Dump For Chunk 8 to 11 = = =
# (pid=25582) exit data routing process 8 .
# (pid=25585) proces 10 has routed 1800000 rows
# (pid=25584) proces 11 has routed 1700000 rows
# (pid=25582) enter data routing process 12 ..
# (pid=25585) proces 10 has routed 1900000 rows
# (pid=25584) proces 11 has routed 1800000 rows
# (pid=25582) proces 12 has routed 0 rows
# (pid=25583) exit data routing process 9 .
# (pid=25584) proces 11 has routed 1900000 rows
# (pid=25582) proces 12 has routed 100000 rows
# (pid=25583) enter data routing process 13 ..
# (pid=25583) proces 13 has routed 0 rows
# (pid=25582) proces 12 has routed 200000 rows
# (pid=25583) proces 13 has routed 100000 rows
# (pid=25585) exit data routing process 10 .
# (pid=25582) proces 12 has routed 300000 rows
# (pid=25585) enter data routing process 14 ..
# (pid=25583) proces 13 has routed 200000 rows
# (pid=25584) exit data routing process 11 .
# (pid=25585) proces 14 has routed 0 rows
# (pid=25582) proces 12 has routed 400000 rows
# (pid=25584) enter data routing process 15 ..
# (pid=25583) proces 13 has routed 300000 rows
# (pid=25585) proces 14 has routed 100000 rows
# (pid=25584) proces 15 has routed 0 rows
# (pid=25582) proces 12 has routed 500000 rows
# (pid=25583) proces 13 has routed 400000 rows
# (pid=25585) proces 14 has routed 200000 rows
# (pid=25584) proces 15 has routed 100000 rows
# (pid=25582) proces 12 has routed 600000 rows
# (pid=25583) proces 13 has routed 500000 rows
# (pid=25585) proces 14 has routed 300000 rows
# (pid=25584) proces 15 has routed 200000 rows
# (pid=25582) proces 12 has routed 700000 rows
# (pid=25583) proces 13 has routed 600000 rows
# (pid=25585) proces 14 has routed 400000 rows
# (pid=25584) proces 15 has routed 300000 rows
# (pid=25582) proces 12 has routed 800000 rows
# (pid=25583) proces 13 has routed 700000 rows
# (pid=25585) proces 14 has routed 500000 rows
# (pid=25584) proces 15 has routed 400000 rows
# (pid=25582) proces 12 has routed 900000 rows
# (pid=25583) proces 13 has routed 800000 rows
# (pid=25585) proces 14 has routed 600000 rows
# (pid=25584) proces 15 has routed 500000 rows
# (pid=25582) proces 12 has routed 1000000 rows
# (pid=25583) proces 13 has routed 900000 rows
# (pid=25585) proces 14 has routed 700000 rows
# (pid=25584) proces 15 has routed 600000 rows
# (pid=25582) proces 12 has routed 1100000 rows
# (pid=25583) proces 13 has routed 1000000 rows
# (pid=25585) proces 14 has routed 800000 rows
# (pid=25584) proces 15 has routed 700000 rows
# (pid=25582) proces 12 has routed 1200000 rows
# (pid=25585) proces 14 has routed 900000 rows
# (pid=25584) proces 15 has routed 800000 rows
# (pid=25583) proces 13 has routed 1100000 rows
# (pid=25582) proces 12 has routed 1300000 rows
# (pid=25585) proces 14 has routed 1000000 rows
# (pid=25583) proces 13 has routed 1200000 rows
# (pid=25584) proces 15 has routed 900000 rows
# (pid=25582) proces 12 has routed 1400000 rows
# = = = Finish Dump For Chunk 8(pid=25583) proces 13 has routed 1300000 rows
# (pid=25584) proces 15 has routed 1000000 rows
# (pid=25585) proces 14 has routed 1100000 rows
# (pid=25582) proces 12 has routed 1500000 rows
# to 11 = = =
# = = = TOTAL PROCESSED SO FAR: 24000000 ROWS. TIME SPENT: 348.4958019256592 SECONDS = = =
# (pid=25585) proces 14 has routed 1200000 rows
# (pid=25584) proces 15 has routed 1100000 rows
# (pid=25583) proces 13 has routed 1400000 rows
# (pid=25582) proces 12 has routed 1600000 rows
# reading chunk:  16
# (pid=25585) proces 14 has routed 1300000 rows
# (pid=25584) proces 15 has routed 1200000 rows
# (pid=25583) proces 13 has routed 1500000 rows
# (pid=25582) proces 12 has routed 1700000 rows
# (pid=25583) proces 13 has routed 1600000 rows
# (pid=25584) proces 15 has routed 1300000 rows
# (pid=25585) proces 14 has routed 1400000 rows
# reading chunk:  17
# (pid=25582) proces 12 has routed 1800000 rows
# (pid=25583) proces 13 has routed 1700000 rows
# (pid=25585) proces 14 has routed 1500000 rows
# (pid=25584) proces 15 has routed 1400000 rows
# (pid=25582) proces 12 has routed 1900000 rows
# reading chunk:  18
# (pid=25585) proces 14 has routed 1600000 rows
# (pid=25584) proces 15 has routed 1500000 rows
# (pid=25583) proces 13 has routed 1800000 rows
# (pid=25585) proces 14 has routed 1700000 rows
# (pid=25584) proces 15 has routed 1600000 rows
# (pid=25583) proces 13 has routed 1900000 rows
# reading chunk:  19
# = = = Process Dump For Chunk 12 to 15 = = =
# (pid=25582) exit data routing process 12 .
# (pid=25584) proces 15 has routed 1700000 rows
# (pid=25585) proces 14 has routed 1800000 rows
# (pid=25582) enter data routing process 16 ..
# (pid=25582) proces 16 has routed 0 rows
# (pid=25584) proces 15 has routed 1800000 rows
# (pid=25585) proces 14 has routed 1900000 rows
# (pid=25583) exit data routing process 13 .
# (pid=25582) proces 16 has routed 100000 rows
# (pid=25583) enter data routing process 17 ..
# (pid=25584) proces 15 has routed 1900000 rows
# (pid=25583) proces 17 has routed 0 rows
# (pid=25582) proces 16 has routed 200000 rows
# (pid=25583) proces 17 has routed 100000 rows
# (pid=25585) exit data routing process 14 .
# (pid=25582) proces 16 has routed 300000 rows
# (pid=25585) enter data routing process 18 ..
# (pid=25584) exit data routing process 15 .
# (pid=25583) proces 17 has routed 200000 rows
# (pid=25585) proces 18 has routed 0 rows
# (pid=25582) proces 16 has routed 400000 rows
# (pid=25584) enter data routing process 19 ..
# (pid=25583) proces 17 has routed 300000 rows
# (pid=25584) proces 19 has routed 0 rows
# (pid=25585) proces 18 has routed 100000 rows
# (pid=25582) proces 16 has routed 500000 rows
# (pid=25584) proces 19 has routed 100000 rows
# (pid=25583) proces 17 has routed 400000 rows
# (pid=25585) proces 18 has routed 200000 rows
# (pid=25582) proces 16 has routed 600000 rows
# (pid=25584) proces 19 has routed 200000 rows
# (pid=25585) proces 18 has routed 300000 rows
# (pid=25583) proces 17 has routed 500000 rows
# (pid=25582) proces 16 has routed 700000 rows
# (pid=25584) proces 19 has routed 300000 rows
# (pid=25583) proces 17 has routed 600000 rows
# (pid=25585) proces 18 has routed 400000 rows
# (pid=25582) proces 16 has routed 800000 rows
# (pid=25584) proces 19 has routed 400000 rows
# (pid=25583) proces 17 has routed 700000 rows
# (pid=25585) proces 18 has routed 500000 rows
# (pid=25582) proces 16 has routed 900000 rows
# (pid=25584) proces 19 has routed 500000 rows
# (pid=25585) proces 18 has routed 600000 rows
# (pid=25583) proces 17 has routed 800000 rows
# (pid=25582) proces 16 has routed 1000000 rows
# (pid=25584) proces 19 has routed 600000 rows
# (pid=25583) proces 17 has routed 900000 rows
# (pid=25585) proces 18 has routed 700000 rows
# (pid=25582) proces 16 has routed 1100000 rows
# (pid=25584) proces 19 has routed 700000 rows
# (pid=25583) proces 17 has routed 1000000 rows
# (pid=25585) proces 18 has routed 800000 rows
# (pid=25582) proces 16 has routed 1200000 rows
# (pid=25584) proces 19 has routed 800000 rows
# (pid=25585) proces 18 has routed 900000 rows
# (pid=25583) proces 17 has routed 1100000 rows
# (pid=25582) proces 16 has routed 1300000 rows
# (pid=25584) proces 19 has routed 900000 rows
# (pid=25585) proces 18 has routed 1000000 rows
# (pid=25583) proces 17 has routed 1200000 rows
# (pid=25582) proces 16 has routed 1400000 rows
# (pid=25584) proces 19 has routed 1000000 rows
# = = = Finish Dump For Chunk(pid=25583) proces 17 has routed 1300000 rows
# (pid=25585) proces 18 has routed 1100000 rows
# (pid=25582) proces 16 has routed 1500000 rows
#  12 to 15 = = =
# = = = TOTAL PROCESSED SO FAR: 32000000 ROWS. TIME SPENT: 440.3457930088043 SECONDS = = =
# (pid=25584) proces 19 has routed 1100000 rows
# (pid=25585) proces 18 has routed 1200000 rows
# (pid=25583) proces 17 has routed 1400000 rows
# (pid=25582) proces 16 has routed 1600000 rows
# reading chunk:  20
# (pid=25584) proces 19 has routed 1200000 rows
# (pid=25585) proces 18 has routed 1300000 rows
# (pid=25583) proces 17 has routed 1500000 rows
# (pid=25582) proces 16 has routed 1700000 rows
# (pid=25584) proces 19 has routed 1300000 rows
# (pid=25583) proces 17 has routed 1600000 rows
# reading chunk:  21
# (pid=25585) proces 18 has routed 1400000 rows
# (pid=25582) proces 16 has routed 1800000 rows
# (pid=25584) proces 19 has routed 1400000 rows
# (pid=25585) proces 18 has routed 1500000 rows
# (pid=25582) proces 16 has routed 1900000 rows
# (pid=25583) proces 17 has routed 1700000 rows
# reading chunk:  22
# (pid=25584) proces 19 has routed 1500000 rows
# (pid=25585) proces 18 has routed 1600000 rows
# (pid=25583) proces 17 has routed 1800000 rows
# (pid=25584) proces 19 has routed 1600000 rows
# reading chunk:  23
# (pid=25583) proces 17 has routed 1900000 rows
# (pid=25585) proces 18 has routed 1700000 rows
# (pid=25582) exit data routing process 16 .
# = = = Process Dump For Chunk 16 to 19 = = =
# (pid=25584) proces 19 has routed 1700000 rows
# (pid=25582) enter data routing process 20 ..
# (pid=25585) proces 18 has routed 1800000 rows
# (pid=25582) proces 20 has routed 0 rows
# (pid=25584) proces 19 has routed 1800000 rows
# (pid=25585) proces 18 has routed 1900000 rows
# (pid=25583) exit data routing process 17 .
# (pid=25582) proces 20 has routed 100000 rows
# (pid=25584) proces 19 has routed 1900000 rows
# (pid=25583) enter data routing process 21 ..
# (pid=25582) proces 20 has routed 200000 rows
# (pid=25583) proces 21 has routed 0 rows
# (pid=25585) exit data routing process 18 .
# (pid=25582) proces 20 has routed 300000 rows
# (pid=25583) proces 21 has routed 100000 rows
# (pid=25584) exit data routing process 19 .
# (pid=25585) enter data routing process 22 ..
# (pid=25582) proces 20 has routed 400000 rows
# (pid=25583) proces 21 has routed 200000 rows
# (pid=25585) proces 22 has routed 0 rows
# (pid=25584) enter data routing process 23 ..
# (pid=25584) proces 23 has routed 0 rows
# (pid=25583) proces 21 has routed 300000 rows
# (pid=25585) proces 22 has routed 100000 rows
# (pid=25582) proces 20 has routed 500000 rows
# (pid=25584) proces 23 has routed 100000 rows
# (pid=25585) proces 22 has routed 200000 rows
# (pid=25583) proces 21 has routed 400000 rows
# (pid=25582) proces 20 has routed 600000 rows
# (pid=25584) proces 23 has routed 200000 rows
# (pid=25585) proces 22 has routed 300000 rows
# (pid=25582) proces 20 has routed 700000 rows
# (pid=25583) proces 21 has routed 500000 rows
# (pid=25584) proces 23 has routed 300000 rows
# (pid=25585) proces 22 has routed 400000 rows
# (pid=25582) proces 20 has routed 800000 rows
# (pid=25583) proces 21 has routed 600000 rows
# (pid=25584) proces 23 has routed 400000 rows
# (pid=25585) proces 22 has routed 500000 rows
# (pid=25583) proces 21 has routed 700000 rows
# (pid=25582) proces 20 has routed 900000 rows
# (pid=25584) proces 23 has routed 500000 rows
# (pid=25585) proces 22 has routed 600000 rows
# (pid=25583) proces 21 has routed 800000 rows
# (pid=25582) proces 20 has routed 1000000 rows
# (pid=25584) proces 23 has routed 600000 rows
# (pid=25585) proces 22 has routed 700000 rows
# (pid=25583) proces 21 has routed 900000 rows
# (pid=25582) proces 20 has routed 1100000 rows
# (pid=25584) proces 23 has routed 700000 rows
# (pid=25585) proces 22 has routed 800000 rows
# (pid=25582) proces 20 has routed 1200000 rows
# (pid=25583) proces 21 has routed 1000000 rows
# (pid=25584) proces 23 has routed 800000 rows
# (pid=25585) proces 22 has routed 900000 rows
# (pid=25583) proces 21 has routed 1100000 rows
# (pid=25582) proces 20 has routed 1300000 rows
# (pid=25584) proces 23 has routed 900000 rows
# (pid=25583) proces 21 has routed 1200000 rows
# (pid=25585) proces 22 has routed 1000000 rows
# (pid=25582) proces 20 has routed 1400000 rows
# = = = Finish Dump For Chunk(pid=25584) proces 23 has routed 1000000 rows 16 to 19 = = =
# = = = TOTAL PROCESSED SO FAR: 40000000 ROWS. TIME SPENT: 531.5426371097565 SECONDS = = =
#
# (pid=25585) proces 22 has routed 1100000 rows
# (pid=25582) proces 20 has routed 1500000 rows
# (pid=25583) proces 21 has routed 1300000 rows
# (pid=25584) proces 23 has routed 1100000 rows
# (pid=25585) proces 22 has routed 1200000 rows
# (pid=25582) proces 20 has routed 1600000 rows
# (pid=25583) proces 21 has routed 1400000 rows
# reading chunk:  24
# (pid=25584) proces 23 has routed 1200000 rows
# (pid=25585) proces 22 has routed 1300000 rows
# (pid=25583) proces 21 has routed 1500000 rows
# (pid=25582) proces 20 has routed 1700000 rows
# (pid=25584) proces 23 has routed 1300000 rows
# reading chunk:  25
# (pid=25585) proces 22 has routed 1400000 rows
# (pid=25583) proces 21 has routed 1600000 rows
# (pid=25582) proces 20 has routed 1800000 rows
# (pid=25584) proces 23 has routed 1400000 rows
# (pid=25585) proces 22 has routed 1500000 rows
# (pid=25582) proces 20 has routed 1900000 rows
# (pid=25583) proces 21 has routed 1700000 rows
# reading chunk:  26
# (pid=25584) proces 23 has routed 1500000 rows
# (pid=25585) proces 22 has routed 1600000 rows
# (pid=25583) proces 21 has routed 1800000 rows
# (pid=25584) proces 23 has routed 1600000 rows
# reading chunk:  27
# (pid=25585) proces 22 has routed 1700000 rows
# (pid=25583) proces 21 has routed 1900000 rows
# = = = Process Dump For Chunk 20 to 23 = = =
# (pid=25582) exit data routing process 20 .
# (pid=25584) proces 23 has routed 1700000 rows
# (pid=25585) proces 22 has routed 1800000 rows
# (pid=25582) enter data routing process 24 ..
# (pid=25582) proces 24 has routed 0 rows
# (pid=25584) proces 23 has routed 1800000 rows
# (pid=25585) proces 22 has routed 1900000 rows
# (pid=25583) exit data routing process 21 .
# (pid=25584) proces 23 has routed 1900000 rows
# (pid=25582) proces 24 has routed 100000 rows
# (pid=25583) enter data routing process 25 ..
# (pid=25583) proces 25 has routed 0 rows
# (pid=25582) proces 24 has routed 200000 rows
# (pid=25585) exit data routing process 22 .
# (pid=25583) proces 25 has routed 100000 rows
# (pid=25582) proces 24 has routed 300000 rows
# (pid=25585) enter data routing process 26 ..
# (pid=25584) exit data routing process 23 .
# (pid=25585) proces 26 has routed 0 rows
# (pid=25583) proces 25 has routed 200000 rows
# (pid=25584) enter data routing process 27 ..
# (pid=25582) proces 24 has routed 400000 rows
# (pid=25584) proces 27 has routed 0 rows
# (pid=25585) proces 26 has routed 100000 rows
# (pid=25583) proces 25 has routed 300000 rows
# (pid=25582) proces 24 has routed 500000 rows
# (pid=25584) proces 27 has routed 100000 rows
# (pid=25585) proces 26 has routed 200000 rows
# (pid=25583) proces 25 has routed 400000 rows
# (pid=25582) proces 24 has routed 600000 rows
# (pid=25584) proces 27 has routed 200000 rows
# (pid=25585) proces 26 has routed 300000 rows
# (pid=25583) proces 25 has routed 500000 rows
# (pid=25582) proces 24 has routed 700000 rows
# (pid=25584) proces 27 has routed 300000 rows
# (pid=25585) proces 26 has routed 400000 rows
# (pid=25583) proces 25 has routed 600000 rows
# (pid=25582) proces 24 has routed 800000 rows
# (pid=25584) proces 27 has routed 400000 rows
# (pid=25585) proces 26 has routed 500000 rows
# (pid=25583) proces 25 has routed 700000 rows
# (pid=25582) proces 24 has routed 900000 rows
# (pid=25584) proces 27 has routed 500000 rows
# (pid=25585) proces 26 has routed 600000 rows
# (pid=25583) proces 25 has routed 800000 rows
# (pid=25582) proces 24 has routed 1000000 rows
# (pid=25584) proces 27 has routed 600000 rows
# (pid=25585) proces 26 has routed 700000 rows
# (pid=25583) proces 25 has routed 900000 rows
# (pid=25584) proces 27 has routed 700000 rows
# (pid=25582) proces 24 has routed 1100000 rows
# (pid=25585) proces 26 has routed 800000 rows
# (pid=25583) proces 25 has routed 1000000 rows
# (pid=25582) proces 24 has routed 1200000 rows
# (pid=25584) proces 27 has routed 800000 rows
# (pid=25585) proces 26 has routed 900000 rows
# (pid=25583) proces 25 has routed 1100000 rows
# (pid=25584) proces 27 has routed 900000 rows
# (pid=25582) proces 24 has routed 1300000 rows
# (pid=25585) proces 26 has routed 1000000 rows
# (pid=25583) proces 25 has routed 1200000 rows
# = = = Finish Dump For Chunk 20 to 23(pid=25584) proces 27 has routed 1000000 rows
# (pid=25582) proces 24 has routed 1400000 rows
# (pid=25585) proces 26 has routed 1100000 rows = = =
# = = = TOTAL PROCESSED SO FAR: 48000000 ROWS. TIME SPENT: 623.5879445075989 SECONDS = = =
#
# (pid=25583) proces 25 has routed 1300000 rows
# (pid=25584) proces 27 has routed 1100000 rows
# (pid=25582) proces 24 has routed 1500000 rows
# (pid=25585) proces 26 has routed 1200000 rows
# (pid=25583) proces 25 has routed 1400000 rows
# reading chunk:  28
# (pid=25584) proces 27 has routed 1200000 rows
# (pid=25582) proces 24 has routed 1600000 rows
# (pid=25585) proces 26 has routed 1300000 rows
# (pid=25583) proces 25 has routed 1500000 rows
# (pid=25584) proces 27 has routed 1300000 rows
# (pid=25582) proces 24 has routed 1700000 rows
# reading chunk:  29
# (pid=25585) proces 26 has routed 1400000 rows
# (pid=25583) proces 25 has routed 1600000 rows
# (pid=25584) proces 27 has routed 1400000 rows
# (pid=25582) proces 24 has routed 1800000 rows
# (pid=25585) proces 26 has routed 1500000 rows
# (pid=25583) proces 25 has routed 1700000 rows
# reading chunk:  (pid=25584) proces 27 has routed 1500000 rows30
#
# (pid=25582) proces 24 has routed 1900000 rows
# (pid=25585) proces 26 has routed 1600000 rows
# (pid=25583) proces 25 has routed 1800000 rows
# (pid=25584) proces 27 has routed 1600000 rows
# reading chunk:  31
# (pid=25585) proces 26 has routed 1700000 rows
# (pid=25583) proces 25 has routed 1900000 rows
# = = = Process Dump For Chunk 24 to 27 = = =
# (pid=25584) proces 27 has routed 1700000 rows
# (pid=25582) exit data routing process 24 .
# (pid=25585) proces 26 has routed 1800000 rows
# (pid=25584) proces 27 has routed 1800000 rows
# (pid=25582) enter data routing process 28 ..
# (pid=25585) proces 26 has routed 1900000 rows
# (pid=25582) proces 28 has routed 0 rows
# (pid=25583) exit data routing process 25 .
# (pid=25584) proces 27 has routed 1900000 rows
# (pid=25583) enter data routing process 29 ..
# (pid=25582) proces 28 has routed 100000 rows
# (pid=25583) proces 29 has routed 0 rows
# (pid=25582) proces 28 has routed 200000 rows
# (pid=25585) exit data routing process 26 .
# (pid=25583) proces 29 has routed 100000 rows
# (pid=25584) exit data routing process 27 .
# (pid=25585) enter data routing process 30 ..
# (pid=25582) proces 28 has routed 300000 rows
# (pid=25585) proces 30 has routed 0 rows
# (pid=25583) proces 29 has routed 200000 rows
# (pid=25584) enter data routing process 31 ..
# (pid=25584) proces 31 has routed 0 rows
# (pid=25582) proces 28 has routed 400000 rows
# (pid=25585) proces 30 has routed 100000 rows
# (pid=25583) proces 29 has routed 300000 rows
# (pid=25584) proces 31 has routed 100000 rows
# (pid=25582) proces 28 has routed 500000 rows
# (pid=25585) proces 30 has routed 200000 rows
# (pid=25583) proces 29 has routed 400000 rows
# (pid=25584) proces 31 has routed 200000 rows
# (pid=25582) proces 28 has routed 600000 rows
# (pid=25585) proces 30 has routed 300000 rows
# (pid=25583) proces 29 has routed 500000 rows
# (pid=25584) proces 31 has routed 300000 rows
# (pid=25582) proces 28 has routed 700000 rows
# (pid=25585) proces 30 has routed 400000 rows
# (pid=25583) proces 29 has routed 600000 rows
# (pid=25584) proces 31 has routed 400000 rows
# (pid=25582) proces 28 has routed 800000 rows
# (pid=25585) proces 30 has routed 500000 rows
# (pid=25583) proces 29 has routed 700000 rows
# (pid=25584) proces 31 has routed 500000 rows
# (pid=25582) proces 28 has routed 900000 rows
# (pid=25585) proces 30 has routed 600000 rows
# (pid=25583) proces 29 has routed 800000 rows
# (pid=25584) proces 31 has routed 600000 rows
# (pid=25582) proces 28 has routed 1000000 rows
# (pid=25585) proces 30 has routed 700000 rows
# (pid=25583) proces 29 has routed 900000 rows
# (pid=25584) proces 31 has routed 700000 rows
# (pid=25582) proces 28 has routed 1100000 rows
# (pid=25585) proces 30 has routed 800000 rows
# (pid=25583) proces 29 has routed 1000000 rows
# (pid=25584) proces 31 has routed 800000 rows
# (pid=25582) proces 28 has routed 1200000 rows
# (pid=25585) proces 30 has routed 900000 rows
# (pid=25583) proces 29 has routed 1100000 rows
# (pid=25584) proces 31 has routed 900000 rows
# (pid=25582) proces 28 has routed 1300000 rows
# (pid=25583) proces 29 has routed 1200000 rows
# (pid=25585) proces 30 has routed 1000000 rows
# (pid=25584) proces 31 has routed 1000000 rows
# (pid=25582) proces 28 has routed 1400000 rows
# (pid=25585) proces 30 has routed 1100000 rows
# (pid=25583) proces 29 has routed 1300000 rows
# (pid=25584) proces 31 has routed 1100000 rows
# (pid=25582) proces 28 has routed 1500000 rows
# (pid=25585) proces 30 has routed 1200000 rows
# (pid=25583) proces 29 has routed 1400000 rows
# = = = Finish Dump For Chunk(pid=25584) proces 31 has routed 1200000 rows
# (pid=25582) proces 28 has routed 1600000 rows
# (pid=25583) proces 29 has routed 1500000 rows
# (pid=25585) proces 30 has routed 1300000 rows
#  24 to 27 = = =
# = = = TOTAL PROCESSED SO FAR: 56000000 ROWS. TIME SPENT: 722.3699839115143 SECONDS = = =
# (pid=25584) proces 31 has routed 1300000 rows
# (pid=25583) proces 29 has routed 1600000 rows
# (pid=25585) proces 30 has routed 1400000 rows
# (pid=25582) proces 28 has routed 1700000 rows
# reading chunk:  32
# (pid=25584) proces 31 has routed 1400000 rows
# (pid=25585) proces 30 has routed 1500000 rows
# (pid=25582) proces 28 has routed 1800000 rows
# (pid=25583) proces 29 has routed 1700000 rows
# (pid=25584) proces 31 has routed 1500000 rows
# reading chunk:  33
# (pid=25585) proces 30 has routed 1600000 rows
# (pid=25582) proces 28 has routed 1900000 rows
# (pid=25583) proces 29 has routed 1800000 rows
# (pid=25584) proces 31 has routed 1600000 rows
# (pid=25583) proces 29 has routed 1900000 rows
# (pid=25585) proces 30 has routed 1700000 rows
# reading chunk:  34
# (pid=25584) proces 31 has routed 1700000 rows
# (pid=25585) proces 30 has routed 1800000 rows
# (pid=25582) exit data routing process 28 .
# (pid=25584) proces 31 has routed 1800000 rows
# reading chunk:  35
# (pid=25585) proces 30 has routed 1900000 rows
# (pid=25582) enter data routing process 32 ..
# = = = Process Dump For Chunk 28 to 31 = = =
# (pid=25583) exit data routing process 29 .
# (pid=25582) proces 32 has routed 0 rows
# (pid=25584) proces 31 has routed 1900000 rows
# (pid=25583) enter data routing process 33 ..
# (pid=25583) proces 33 has routed 0 rows
# (pid=25582) proces 32 has routed 100000 rows
# (pid=25585) exit data routing process 30 .
# (pid=25583) proces 33 has routed 100000 rows
# (pid=25582) proces 32 has routed 200000 rows
# (pid=25585) enter data routing process 34 ..
# (pid=25584) exit data routing process 31 .
# (pid=25585) proces 34 has routed 0 rows
# (pid=25583) proces 33 has routed 200000 rows
# (pid=25582) proces 32 has routed 300000 rows
# (pid=25584) enter data routing process 35 ..
# (pid=25584) proces 35 has routed 0 rows
# (pid=25585) proces 34 has routed 100000 rows
# (pid=25583) proces 33 has routed 300000 rows
# (pid=25582) proces 32 has routed 400000 rows
# (pid=25584) proces 35 has routed 100000 rows
# (pid=25585) proces 34 has routed 200000 rows
# (pid=25583) proces 33 has routed 400000 rows
# (pid=25582) proces 32 has routed 500000 rows
# (pid=25584) proces 35 has routed 200000 rows
# (pid=25585) proces 34 has routed 300000 rows
# (pid=25583) proces 33 has routed 500000 rows
# (pid=25582) proces 32 has routed 600000 rows
# (pid=25584) proces 35 has routed 300000 rows
# (pid=25585) proces 34 has routed 400000 rows
# (pid=25582) proces 32 has routed 700000 rows
# (pid=25583) proces 33 has routed 600000 rows
# (pid=25584) proces 35 has routed 400000 rows
# (pid=25585) proces 34 has routed 500000 rows
# (pid=25583) proces 33 has routed 700000 rows
# (pid=25582) proces 32 has routed 800000 rows
# (pid=25584) proces 35 has routed 500000 rows
# (pid=25585) proces 34 has routed 600000 rows
# (pid=25582) proces 32 has routed 900000 rows
# (pid=25583) proces 33 has routed 800000 rows
# (pid=25584) proces 35 has routed 600000 rows
# (pid=25585) proces 34 has routed 700000 rows
# (pid=25583) proces 33 has routed 900000 rows
# (pid=25582) proces 32 has routed 1000000 rows
# (pid=25584) proces 35 has routed 700000 rows
# (pid=25585) proces 34 has routed 800000 rows
# (pid=25582) proces 32 has routed 1100000 rows
# (pid=25583) proces 33 has routed 1000000 rows
# (pid=25584) proces 35 has routed 800000 rows
# (pid=25585) proces 34 has routed 900000 rows
# (pid=25582) proces 32 has routed 1200000 rows
# (pid=25583) proces 33 has routed 1100000 rows
# (pid=25584) proces 35 has routed 900000 rows
# (pid=25583) proces 33 has routed 1200000 rows
# (pid=25585) proces 34 has routed 1000000 rows
# (pid=25582) proces 32 has routed 1300000 rows
# (pid=25584) proces 35 has routed 1000000 rows
# = = = Finish Dump For Chunk(pid=25585) proces 34 has routed 1100000 rows
# (pid=25582) proces 32 has routed 1400000 rows
# (pid=25583) proces 33 has routed 1300000 rows
#  28 to 31 = = =
# = = = TOTAL PROCESSED SO FAR: 64000000 ROWS. TIME SPENT: 807.5928251743317 SECONDS = = =
# (pid=25584) proces 35 has routed 1100000 rows
# (pid=25585) proces 34 has routed 1200000 rows
# (pid=25582) proces 32 has routed 1500000 rows
# (pid=25583) proces 33 has routed 1400000 rows
# reading chunk:  36
# (pid=25584) proces 35 has routed 1200000 rows
# (pid=25582) proces 32 has routed 1600000 rows
# (pid=25583) proces 33 has routed 1500000 rows
# (pid=25585) proces 34 has routed 1300000 rows
# (pid=25584) proces 35 has routed 1300000 rows
# (pid=25583) proces 33 has routed 1600000 rows
# (pid=25585) proces 34 has routed 1400000 rows
# (pid=25582) proces 32 has routed 1700000 rows
# reading chunk:  37
# (pid=25584) proces 35 has routed 1400000 rows
# (pid=25585) proces 34 has routed 1500000 rows
# (pid=25582) proces 32 has routed 1800000 rows
# (pid=25583) proces 33 has routed 1700000 rows
# reading chunk:  38
# (pid=25584) proces 35 has routed 1500000 rows
# (pid=25585) proces 34 has routed 1600000 rows
# (pid=25582) proces 32 has routed 1900000 rows
# (pid=25583) proces 33 has routed 1800000 rows
# (pid=25584) proces 35 has routed 1600000 rows
# (pid=25583) proces 33 has routed 1900000 rows
# (pid=25585) proces 34 has routed 1700000 rows
# reading chunk:  39
# = = = Process Dump For Chunk 32 to 35 = = =
# (pid=25584) proces 35 has routed 1700000 rows
# (pid=25585) proces 34 has routed 1800000 rows
# (pid=25582) exit data routing process 32 .
# (pid=25582) enter data routing process 36 ..
# (pid=25584) proces 35 has routed 1800000 rows
# (pid=25585) proces 34 has routed 1900000 rows
# (pid=25583) exit data routing process 33 .
# (pid=25582) proces 36 has routed 0 rows
# (pid=25584) proces 35 has routed 1900000 rows
# (pid=25583) enter data routing process 37 ..
# (pid=25582) proces 36 has routed 100000 rows
# (pid=25583) proces 37 has routed 0 rows
# (pid=25585) exit data routing process 34 .
# (pid=25583) proces 37 has routed 100000 rows
# (pid=25582) proces 36 has routed 200000 rows
# (pid=25585) enter data routing process 38 ..
# (pid=25584) exit data routing process 35 .
# (pid=25582) proces 36 has routed 300000 rows
# (pid=25583) proces 37 has routed 200000 rows
# (pid=25585) proces 38 has routed 0 rows
# (pid=25584) enter data routing process 39 ..
# (pid=25582) proces 36 has routed 400000 rows
# (pid=25584) proces 39 has routed 0 rows
# (pid=25583) proces 37 has routed 300000 rows
# (pid=25585) proces 38 has routed 100000 rows
# (pid=25584) proces 39 has routed 100000 rows
# (pid=25582) proces 36 has routed 500000 rows
# (pid=25583) proces 37 has routed 400000 rows
# (pid=25585) proces 38 has routed 200000 rows
# (pid=25584) proces 39 has routed 200000 rows
# (pid=25583) proces 37 has routed 500000 rows
# (pid=25582) proces 36 has routed 600000 rows
# (pid=25585) proces 38 has routed 300000 rows
# (pid=25584) proces 39 has routed 300000 rows
# (pid=25582) proces 36 has routed 700000 rows
# (pid=25583) proces 37 has routed 600000 rows
# (pid=25585) proces 38 has routed 400000 rows
# (pid=25584) proces 39 has routed 400000 rows
# (pid=25583) proces 37 has routed 700000 rows
# (pid=25582) proces 36 has routed 800000 rows
# (pid=25585) proces 38 has routed 500000 rows
# (pid=25584) proces 39 has routed 500000 rows
# (pid=25582) proces 36 has routed 900000 rows
# (pid=25583) proces 37 has routed 800000 rows
# (pid=25585) proces 38 has routed 600000 rows
# (pid=25584) proces 39 has routed 600000 rows
# (pid=25583) proces 37 has routed 900000 rows
# (pid=25582) proces 36 has routed 1000000 rows
# (pid=25585) proces 38 has routed 700000 rows
# (pid=25584) proces 39 has routed 700000 rows
# (pid=25582) proces 36 has routed 1100000 rows
# (pid=25583) proces 37 has routed 1000000 rows
# (pid=25585) proces 38 has routed 800000 rows
# (pid=25584) proces 39 has routed 800000 rows
# (pid=25582) proces 36 has routed 1200000 rows
# (pid=25583) proces 37 has routed 1100000 rows
# (pid=25585) proces 38 has routed 900000 rows
# (pid=25584) proces 39 has routed 900000 rows
# (pid=25583) proces 37 has routed 1200000 rows
# (pid=25582) proces 36 has routed 1300000 rows
# (pid=25585) proces 38 has routed 1000000 rows
# (pid=25584) proces 39 has routed 1000000 rows
# (pid=25582) proces 36 has routed 1400000 rows
# (pid=25583) proces 37 has routed 1300000 rows
# (pid=25585) proces 38 has routed 1100000 rows
# (pid=25584) proces 39 has routed 1100000 rows
# (pid=25582) proces 36 has routed 1500000 rows
# = = = Finish Dump For Chunk 32 to 35 = = =
# = = = TOTAL PROCESSED SO FAR: 72000000 ROWS. TIME SPENT: 903.1911532878876 SECONDS = = =
# (pid=25583) proces 37 has routed 1400000 rows
# (pid=25585) proces 38 has routed 1200000 rows
# (pid=25584) proces 39 has routed 1200000 rows
# (pid=25582) proces 36 has routed 1600000 rows
# (pid=25583) proces 37 has routed 1500000 rows
# (pid=25585) proces 38 has routed 1300000 rows
# reading chunk:  40
# (pid=25584) proces 39 has routed 1300000 rows
# (pid=25583) proces 37 has routed 1600000 rows
# (pid=25582) proces 36 has routed 1700000 rows
# (pid=25585) proces 38 has routed 1400000 rows
# (pid=25584) proces 39 has routed 1400000 rows
# (pid=25582) proces 36 has routed 1800000 rows
# (pid=25583) proces 37 has routed 1700000 rows
# reading chunk:  41
# (pid=25585) proces 38 has routed 1500000 rows
# (pid=25584) proces 39 has routed 1500000 rows
# (pid=25582) proces 36 has routed 1900000 rows
# (pid=25583) proces 37 has routed 1800000 rows
# (pid=25585) proces 38 has routed 1600000 rows
# reading chunk:  42
# (pid=25584) proces 39 has routed 1600000 rows
# (pid=25583) proces 37 has routed 1900000 rows
# (pid=25585) proces 38 has routed 1700000 rows
# (pid=25584) proces 39 has routed 1700000 rows
# (pid=25582) exit data routing process 36 .reading chunk:
#  43
# (pid=25585) proces 38 has routed 1800000 rows
# = = = Process Dump For Chunk 36 to 39 = = =
# (pid=25582) enter data routing process 40 ..
# (pid=25584) proces 39 has routed 1800000 rows
# (pid=25582) proces 40 has routed 0 rows
# (pid=25583) exit data routing process 37 .
# (pid=25585) proces 38 has routed 1900000 rows
# (pid=25584) proces 39 has routed 1900000 rows
# (pid=25583) enter data routing process 41 ..
# (pid=25582) proces 40 has routed 100000 rows
# (pid=25583) proces 41 has routed 0 rows
# (pid=25582) proces 40 has routed 200000 rows
# (pid=25583) proces 41 has routed 100000 rows
# (pid=25585) exit data routing process 38 .
# (pid=25584) exit data routing process 39 .
# (pid=25582) proces 40 has routed 300000 rows
# (pid=25583) proces 41 has routed 200000 rows
# (pid=25585) enter data routing process 42 ..
# (pid=25584) enter data routing process 43 ..
# (pid=25585) proces 42 has routed 0 rows
# (pid=25584) proces 43 has routed 0 rows
# (pid=25582) proces 40 has routed 400000 rows
# (pid=25583) proces 41 has routed 300000 rows
# (pid=25585) proces 42 has routed 100000 rows
# (pid=25584) proces 43 has routed 100000 rows
# (pid=25583) proces 41 has routed 400000 rows
# (pid=25582) proces 40 has routed 500000 rows
# (pid=25585) proces 42 has routed 200000 rows
# (pid=25584) proces 43 has routed 200000 rows
# (pid=25583) proces 41 has routed 500000 rows
# (pid=25582) proces 40 has routed 600000 rows
# (pid=25585) proces 42 has routed 300000 rows
# (pid=25584) proces 43 has routed 300000 rows
# (pid=25582) proces 40 has routed 700000 rows
# (pid=25583) proces 41 has routed 600000 rows
# (pid=25585) proces 42 has routed 400000 rows
# (pid=25584) proces 43 has routed 400000 rows
# (pid=25583) proces 41 has routed 700000 rows
# (pid=25582) proces 40 has routed 800000 rows
# (pid=25585) proces 42 has routed 500000 rows
# (pid=25584) proces 43 has routed 500000 rows
# (pid=25582) proces 40 has routed 900000 rows
# (pid=25583) proces 41 has routed 800000 rows
# (pid=25585) proces 42 has routed 600000 rows
# (pid=25584) proces 43 has routed 600000 rows
# (pid=25583) proces 41 has routed 900000 rows
# (pid=25582) proces 40 has routed 1000000 rows
# (pid=25585) proces 42 has routed 700000 rows
# (pid=25584) proces 43 has routed 700000 rows
# (pid=25583) proces 41 has routed 1000000 rows
# (pid=25582) proces 40 has routed 1100000 rows
# (pid=25585) proces 42 has routed 800000 rows
# (pid=25584) proces 43 has routed 800000 rows
# (pid=25583) proces 41 has routed 1100000 rows
# (pid=25582) proces 40 has routed 1200000 rows
# (pid=25584) proces 43 has routed 900000 rows
# (pid=25585) proces 42 has routed 900000 rows
# (pid=25583) proces 41 has routed 1200000 rows
# (pid=25582) proces 40 has routed 1300000 rows
# (pid=25584) proces 43 has routed 1000000 rows
# (pid=25585) proces 42 has routed 1000000 rows
# (pid=25583) proces 41 has routed 1300000 rows
# (pid=25582) proces 40 has routed 1400000 rows
# (pid=25584) proces 43 has routed 1100000 rows
# (pid=25585) proces 42 has routed 1100000 rows
# (pid=25582) proces 40 has routed 1500000 rows
# (pid=25583) proces 41 has routed 1400000 rows
# = = = Finish Dump For Chunk 36 to 39 = = =
# = = = TOTAL PROCESSED SO FAR: 80000000 ROWS. TIME SPENT: 995.4023332595825 SECONDS = = =
# (pid=25584) proces 43 has routed 1200000 rows
# (pid=25582) proces 40 has routed 1600000 rows
# (pid=25583) proces 41 has routed 1500000 rows
# (pid=25585) proces 42 has routed 1200000 rows
# (pid=25583) proces 41 has routed 1600000 rows
# (pid=25584) proces 43 has routed 1300000 rows
# reading chunk:  44
# (pid=25582) proces 40 has routed 1700000 rows
# (pid=25585) proces 42 has routed 1300000 rows
# (pid=25584) proces 43 has routed 1400000 rows
# (pid=25582) proces 40 has routed 1800000 rows
# (pid=25583) proces 41 has routed 1700000 rows
# (pid=25585) proces 42 has routed 1400000 rows
# reading chunk:  45
# (pid=25584) proces 43 has routed 1500000 rows
# (pid=25582) proces 40 has routed 1900000 rows
# (pid=25583) proces 41 has routed 1800000 rows
# (pid=25585) proces 42 has routed 1500000 rows
# (pid=25584) proces 43 has routed 1600000 rows
# reading chunk:  46
# (pid=25583) proces 41 has routed 1900000 rows
# (pid=25585) proces 42 has routed 1600000 rows
# (pid=25584) proces 43 has routed 1700000 rows
# (pid=25582) exit data routing process 40 .
# reading chunk:  47
# (pid=25585) proces 42 has routed 1700000 rows
# = = = Process Dump For Chunk 40 to 43 = = =
# (pid=25584) proces 43 has routed 1800000 rows
# (pid=25582) enter data routing process 44 ..
# (pid=25583) exit data routing process 41 .
# (pid=25585) proces 42 has routed 1800000 rows
# (pid=25582) proces 44 has routed 0 rows
# (pid=25584) proces 43 has routed 1900000 rows
# (pid=25583) enter data routing process 45 ..
# (pid=25585) proces 42 has routed 1900000 rows
# (pid=25583) proces 45 has routed 0 rows
# (pid=25582) proces 44 has routed 100000 rows
# (pid=25583) proces 45 has routed 100000 rows
# (pid=25582) proces 44 has routed 200000 rows
# (pid=25584) exit data routing process 43 .
# (pid=25583) proces 45 has routed 200000 rows
# (pid=25582) proces 44 has routed 300000 rows
# (pid=25585) exit data routing process 42 .
# (pid=25584) enter data routing process 46 ..
# (pid=25583) proces 45 has routed 300000 rows
# (pid=25584) proces 46 has routed 0 rows
# (pid=25585) enter data routing process 47 ..
# (pid=25582) proces 44 has routed 400000 rows
# (pid=25585) proces 47 has routed 0 rows
# (pid=25584) proces 46 has routed 100000 rows
# (pid=25583) proces 45 has routed 400000 rows
# (pid=25582) proces 44 has routed 500000 rows
# (pid=25585) proces 47 has routed 100000 rows
# (pid=25584) proces 46 has routed 200000 rows
# (pid=25583) proces 45 has routed 500000 rows
# (pid=25582) proces 44 has routed 600000 rows
# (pid=25585) proces 47 has routed 200000 rows
# (pid=25584) proces 46 has routed 300000 rows
# (pid=25583) proces 45 has routed 600000 rows
# (pid=25582) proces 44 has routed 700000 rows
# (pid=25585) proces 47 has routed 300000 rows
# (pid=25584) proces 46 has routed 400000 rows
# (pid=25583) proces 45 has routed 700000 rows
# (pid=25582) proces 44 has routed 800000 rows
# (pid=25585) proces 47 has routed 400000 rows
# (pid=25584) proces 46 has routed 500000 rows
# (pid=25583) proces 45 has routed 800000 rows
# (pid=25582) proces 44 has routed 900000 rows
# (pid=25585) proces 47 has routed 500000 rows
# (pid=25583) proces 45 has routed 900000 rows
# (pid=25584) proces 46 has routed 600000 rows
# (pid=25582) proces 44 has routed 1000000 rows
# ...
# (pid=25585) proces 142 has routed 0 rows
# (pid=25583) proces 141 has routed 200000 rowsreading chunk:  143
#
# (pid=25584) proces 139 has routed 1600000 rows
# (pid=25582) proces 140 has routed 400000 rows
# = = = Process Dump For Chunk 136 to 139 = = =
# (pid=25585) proces 142 has routed 100000 rows
# (pid=25583) proces 141 has routed 300000 rows
# (pid=25584) proces 139 has routed 1700000 rows
# (pid=25582) proces 140 has routed 500000 rows
# (pid=25585) proces 142 has routed 200000 rows
# (pid=25583) proces 141 has routed 400000 rows
# (pid=25584) proces 139 has routed 1800000 rows
# (pid=25582) proces 140 has routed 600000 rows
# (pid=25585) proces 142 has routed 300000 rows
# (pid=25583) proces 141 has routed 500000 rows
# (pid=25584) proces 139 has routed 1900000 rows
# (pid=25582) proces 140 has routed 700000 rows
# (pid=25585) proces 142 has routed 400000 rows
# (pid=25583) proces 141 has routed 600000 rows
# (pid=25582) proces 140 has routed 800000 rows
# (pid=25585) proces 142 has routed 500000 rows
# (pid=25583) proces 141 has routed 700000 rows
# (pid=25584) exit data routing process 139 .
# (pid=25582) proces 140 has routed 900000 rows
# (pid=25585) proces 142 has routed 600000 rows
# (pid=25583) proces 141 has routed 800000 rows
# (pid=25584) enter data routing process 143 ..
# (pid=25582) proces 140 has routed 1000000 rows
# (pid=25584) proces 143 has routed 0 rows
# (pid=25585) proces 142 has routed 700000 rows
# (pid=25583) proces 141 has routed 900000 rows
# (pid=25582) proces 140 has routed 1100000 rows
# (pid=25584) proces 143 has routed 100000 rows
# (pid=25585) proces 142 has routed 800000 rows
# (pid=25583) proces 141 has routed 1000000 rows
# (pid=25582) proces 140 has routed 1200000 rows
# (pid=25584) proces 143 has routed 200000 rows
# (pid=25585) proces 142 has routed 900000 rows
# (pid=25583) proces 141 has routed 1100000 rows
# (pid=25584) proces 143 has routed 300000 rows
# (pid=25582) proces 140 has routed 1300000 rows
# (pid=25585) proces 142 has routed 1000000 rows
# (pid=25583) proces 141 has routed 1200000 rows
# (pid=25584) proces 143 has routed 400000 rows
# (pid=25582) proces 140 has routed 1400000 rows
# (pid=25585) proces 142 has routed 1100000 rows
# (pid=25583) proces 141 has routed 1300000 rows
# (pid=25582) proces 140 has routed 1500000 rows
# (pid=25584) proces 143 has routed 500000 rows
# (pid=25585) proces 142 has routed 1200000 rows
# (pid=25583) proces 141 has routed 1400000 rows
# (pid=25582) proces 140 has routed 1600000 rows
# (pid=25584) proces 143 has routed 600000 rows
# (pid=25585) proces 142 has routed 1300000 rows
# (pid=25583) proces 141 has routed 1500000 rows
# (pid=25584) proces 143 has routed 700000 rows
# (pid=25582) proces 140 has routed 1700000 rows
# (pid=25585) proces 142 has routed 1400000 rows
# (pid=25583) proces 141 has routed 1600000 rows
# (pid=25582) proces 140 has routed 1800000 rows
# (pid=25584) proces 143 has routed 800000 rows
# (pid=25585) proces 142 has routed 1500000 rows
# (pid=25583) proces 141 has routed 1700000 rows
# (pid=25582) proces 140 has routed 1900000 rows
# (pid=25584) proces 143 has routed 900000 rows
# (pid=25585) proces 142 has routed 1600000 rows
# (pid=25583) proces 141 has routed 1800000 rows
# (pid=25584) proces 143 has routed 1000000 rows
# (pid=25585) proces 142 has routed 1700000 rows
# (pid=25583) proces 141 has routed 1900000 rows= = = Finish Dump For Chunk
# (pid=25584) proces 143 has routed 1100000 rows
#  136 to 139 = = =
# = = = TOTAL PROCESSED SO FAR: 280000000 ROWS. TIME SPENT: 3327.0394854545593 SECONDS = = =
# (pid=25582) exit data routing process 140 .
# (pid=25585) proces 142 has routed 1800000 rows
# (pid=25584) proces 143 has routed 1200000 rows
# (pid=25585) proces 142 has routed 1900000 rows
# reading chunk:  144
# (pid=25583) exit data routing process 141 .
# (pid=25582) enter data routing process 144 ..
# (pid=25584) proces 143 has routed 1300000 rows
# (pid=25582) proces 144 has routed 0 rows
# reading chunk:  145
# (pid=25584) proces 143 has routed 1400000 rows
# (pid=25582) proces 144 has routed 100000 rows
# (pid=25585) exit data routing process 142 .
# (pid=25583) enter data routing process 145 ..
# (pid=25583) proces 145 has routed 0 rows
# (pid=25584) proces 143 has routed 1500000 rows
# reading chunk:  146
# (pid=25582) proces 144 has routed 200000 rows
# (pid=25583) proces 145 has routed 100000 rows
# (pid=25584) proces 143 has routed 1600000 rows
# (pid=25585) enter data routing process 146 ..
# (pid=25582) proces 144 has routed 300000 rows
# (pid=25585) proces 146 has routed 0 rows
# reading chunk:  147
# (pid=25583) proces 145 has routed 200000 rows
# (pid=25584) proces 143 has routed 1700000 rows
# (pid=25582) proces 144 has routed 400000 rows
# = = = Process Dump For Chunk 140 to 143 = = =
# (pid=25585) proces 146 has routed 100000 rows
# (pid=25583) proces 145 has routed 300000 rows
# (pid=25584) proces 143 has routed 1800000 rows
# (pid=25582) proces 144 has routed 500000 rows
# (pid=25585) proces 146 has routed 200000 rows
# (pid=25583) proces 145 has routed 400000 rows
# (pid=25584) proces 143 has routed 1900000 rows
# (pid=25582) proces 144 has routed 600000 rows
# (pid=25585) proces 146 has routed 300000 rows
# (pid=25583) proces 145 has routed 500000 rows
# (pid=25582) proces 144 has routed 700000 rows
# (pid=25585) proces 146 has routed 400000 rows
# (pid=25583) proces 145 has routed 600000 rows
# (pid=25584) exit data routing process 143 .
# (pid=25582) proces 144 has routed 800000 rows
# (pid=25585) proces 146 has routed 500000 rows
# (pid=25584) enter data routing process 147 ..
# (pid=25583) proces 145 has routed 700000 rows
# (pid=25582) proces 144 has routed 900000 rows
# (pid=25584) proces 147 has routed 0 rows
# (pid=25585) proces 146 has routed 600000 rows
# (pid=25583) proces 145 has routed 800000 rows
# (pid=25584) proces 147 has routed 100000 rows
# (pid=25582) proces 144 has routed 1000000 rows
# (pid=25585) proces 146 has routed 700000 rows
# (pid=25583) proces 145 has routed 900000 rows
# (pid=25584) proces 147 has routed 200000 rows
# (pid=25582) proces 144 has routed 1100000 rows
# (pid=25585) proces 146 has routed 800000 rows
# (pid=25583) proces 145 has routed 1000000 rows
# (pid=25584) proces 147 has routed 300000 rows
# (pid=25582) proces 144 has routed 1200000 rows
# (pid=25585) proces 146 has routed 900000 rows
# (pid=25583) proces 145 has routed 1100000 rows
# (pid=25584) proces 147 has routed 400000 rows
# (pid=25582) proces 144 has routed 1300000 rows
# (pid=25585) proces 146 has routed 1000000 rows
# (pid=25583) proces 145 has routed 1200000 rows
# (pid=25584) proces 147 has routed 500000 rows
# (pid=25582) proces 144 has routed 1400000 rows
# (pid=25585) proces 146 has routed 1100000 rows
# (pid=25583) proces 145 has routed 1300000 rows
# (pid=25582) proces 144 has routed 1500000 rows
# (pid=25584) proces 147 has routed 600000 rows
# (pid=25585) proces 146 has routed 1200000 rows
# (pid=25583) proces 145 has routed 1400000 rows
# (pid=25582) proces 144 has routed 1600000 rows
# (pid=25584) proces 147 has routed 700000 rows
# (pid=25585) proces 146 has routed 1300000 rows
# (pid=25583) proces 145 has routed 1500000 rows
# (pid=25584) proces 147 has routed 800000 rows
# (pid=25582) proces 144 has routed 1700000 rows
# (pid=25585) proces 146 has routed 1400000 rows
# (pid=25583) proces 145 has routed 1600000 rows
# (pid=25582) proces 144 has routed 1800000 rows
# (pid=25584) proces 147 has routed 900000 rows
# (pid=25585) proces 146 has routed 1500000 rows
# (pid=25583) proces 145 has routed 1700000 rows
# (pid=25582) proces 144 has routed 1900000 rows
# (pid=25584) proces 147 has routed 1000000 rows
# (pid=25585) proces 146 has routed 1600000 rows
# = = = Finish Dump For Chunk 140 to 143 = = =
# = = = TOTAL PROCESSED SO FAR: 288000000 ROWS. TIME SPENT: 3419.7263247966766 SECONDS = = =
# (pid=25583) proces 145 has routed 1800000 rows
# (pid=25584) proces 147 has routed 1100000 rows
# (pid=25585) proces 146 has routed 1700000 rows
# (pid=25583) proces 145 has routed 1900000 rows
# (pid=25584) proces 147 has routed 1200000 rows
# (pid=25582) exit data routing process 144 .
# (pid=25585) proces 146 has routed 1800000 rows
# reading chunk:  148
# (pid=25584) proces 147 has routed 1300000 rows
# (pid=25585) proces 146 has routed 1900000 rows
# (pid=25582) enter data routing process 148 ..
# (pid=25582) proces 148 has routed 0 rows
# (pid=25583) exit data routing process 145 .
# reading chunk:  149
# (pid=25584) proces 147 has routed 1400000 rows
# reading chunk:  150
# = = = Process Dump For Last Few Chunks = = =
# (pid=25582) proces 148 has routed 100000 rows
# (pid=25583) enter data routing process 149 ..
# (pid=25584) proces 147 has routed 1500000 rows
# (pid=25583) proces 149 has routed 0 rows
# (pid=25585) exit data routing process 146 .
# (pid=25582) proces 148 has routed 200000 rows
# (pid=25585) enter data routing process 150 ..
# (pid=25585) proces 150 has routed 0 rows
# (pid=25585) exit data routing process 150 .
# (pid=25584) proces 147 has routed 1600000 rows
# (pid=25583) proces 149 has routed 100000 rows
# (pid=25582) proces 148 has routed 300000 rows
# (pid=25583) proces 149 has routed 200000 rows
# (pid=25584) proces 147 has routed 1700000 rows
# (pid=25582) proces 148 has routed 400000 rows
# (pid=25583) proces 149 has routed 300000 rows
# (pid=25584) proces 147 has routed 1800000 rows
# (pid=25582) proces 148 has routed 500000 rows
# (pid=25583) proces 149 has routed 400000 rows
# (pid=25584) proces 147 has routed 1900000 rows
# (pid=25582) proces 148 has routed 600000 rows
# (pid=25583) proces 149 has routed 500000 rows
# (pid=25582) proces 148 has routed 700000 rows
# (pid=25583) proces 149 has routed 600000 rows
# (pid=25584) exit data routing process 147 .
# (pid=25582) proces 148 has routed 800000 rows
# (pid=25583) proces 149 has routed 700000 rows
# (pid=25582) proces 148 has routed 900000 rows
# (pid=25583) proces 149 has routed 800000 rows
# (pid=25582) proces 148 has routed 1000000 rows
# (pid=25583) proces 149 has routed 900000 rows
# (pid=25582) proces 148 has routed 1100000 rows
# (pid=25583) proces 149 has routed 1000000 rows
# (pid=25582) proces 148 has routed 1200000 rows
# (pid=25583) proces 149 has routed 1100000 rows
# (pid=25582) proces 148 has routed 1300000 rows
# (pid=25583) proces 149 has routed 1200000 rows
# (pid=25582) proces 148 has routed 1400000 rows
# (pid=25583) proces 149 has routed 1300000 rows
# (pid=25582) proces 148 has routed 1500000 rows
# (pid=25583) proces 149 has routed 1400000 rows
# (pid=25582) proces 148 has routed 1600000 rows
# (pid=25583) proces 149 has routed 1500000 rows
# (pid=25582) proces 148 has routed 1700000 rows
# (pid=25583) proces 149 has routed 1600000 rows
# (pid=25582) proces 148 has routed 1800000 rows
# (pid=25583) proces 149 has routed 1700000 rows
# (pid=25582) proces 148 has routed 1900000 rows
# (pid=25583) proces 149 has routed 1800000 rows
# (pid=25583) proces 149 has routed 1900000 rows
# (pid=25582) exit data routing process 148 .
# (pid=25583) exit data routing process 149 .
# = = = Start Merging the Epochs = = =
# (pid=25585) 2021-07-20 21:12:24,760 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=25584) 2021-07-20 21:12:24,757 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=25582) 2021-07-20 21:12:24,789 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=25583) 2021-07-20 21:12:24,923 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# (pid=25584) process 1 pid 115  len parquets (epochs): 38
# (pid=25582) process 0 pid 62  len parquets (epochs): 38
# (pid=25585) process 3 pid 94  len parquets (epochs): 38
# (pid=25583) process 2 pid 123  len parquets (epochs): 38
# (pid=25585) process 3 pid 95  len parquets (epochs): 38
# (pid=25583) process 2 pid 124  len parquets (epochs): 38
# (pid=25584) process 1 pid 116  len parquets (epochs): 38
# (pid=25583) process 2 pid 84  len parquets (epochs): 38
# (pid=25584) process 1 pid 117  len parquets (epochs): 38
# (pid=25585) process 3 pid 96  len parquets (epochs): 38
# (pid=25584) process 1 pid 118  len parquets (epochs): 38
# (pid=25583) process 2 pid 85  len parquets (epochs): 38
# (pid=25582) process 0 pid 63  len parquets (epochs): 38
# (pid=25585) process 3 pid 137  len parquets (epochs): 38
# (pid=25584) process 1 pid 19  len parquets (epochs): 38
# (pid=25583) process 2 pid 86  len parquets (epochs): 38
# (pid=25585) process 3 pid 138  len parquets (epochs): 38
# (pid=25584) process 1 pid 20  len parquets (epochs): 38
# (pid=25583) process 2 pid 125  len parquets (epochs): 38
# (pid=25584) process 1 pid 21  len parquets (epochs): 38
# (pid=25585) process 3 pid 139  len parquets (epochs): 38
# (pid=25583) process 2 pid 126  len parquets (epochs): 38
# (pid=25582) process 0 pid 107  len parquets (epochs): 38
# (pid=25585) process 3 pid 140  len parquets (epochs): 38
# (pid=25583) process 2 pid 127  len parquets (epochs): 38
# (pid=25582) process 0 pid 108  len parquets (epochs): 38
# (pid=25585) process 3 pid 141  len parquets (epochs): 38
# (pid=25583) process 2 pid 128  len parquets (epochs): 38
# (pid=25582) process 0 pid 109  len parquets (epochs): 38
# (pid=25583) process 2 pid 129  len parquets (epochs): 38
# (pid=25585) process 3 pid 142  len parquets (epochs): 38
# (pid=25583) process 2 pid 130  len parquets (epochs): 38
# (pid=25582) process 0 pid 110  len parquets (epochs): 38
# (pid=25583) process 2 pid 90  len parquets (epochs): 38
# (pid=25585) process 3 pid 100  len parquets (epochs): 38
# (pid=25582) process 0 pid 35  len parquets (epochs): 38
# (pid=25583) process 2 pid 131  len parquets (epochs): 38
# (pid=25585) process 3 pid 143  len parquets (epochs): 38
# (pid=25582) process 0 pid 36  len parquets (epochs): 38
# (pid=25583) process 2 pid 132  len parquets (epochs): 38
# (pid=25585) process 3 pid 144  len parquets (epochs): 38
# (pid=25583) process 2 pid 133  len parquets (epochs): 38
# (pid=25585) process 3 pid 145  len parquets (epochs): 38
# (pid=25583) process 2 pid 134  len parquets (epochs): 38
# (pid=25585) process 3 pid 146  len parquets (epochs): 38
# (pid=25585) process 3 pid 58  len parquets (epochs): 38
# (pid=25583) process 2 pid 135  len parquets (epochs): 38
# (pid=25583) process 2 pid 136  len parquets (epochs): 38
# (pid=25582) process 0 pid 37  len parquets (epochs): 38
# (pid=25584) process 1 pid 22  len parquets (epochs): 38
# (pid=25583) process 2 pid 53  len parquets (epochs): 38
# (pid=25583) exit merge process 2
# (pid=25582) process 0 pid 66  len parquets (epochs): 38
# (pid=25585) process 3 pid 59  len parquets (epochs): 38
# (pid=25582) process 0 pid 67  len parquets (epochs): 38
# (pid=25585) process 3 pid 103  len parquets (epochs): 38
# (pid=25585) process 3 pid 104  len parquets (epochs): 38
# (pid=25585) process 3 pid 105  len parquets (epochs): 38
# (pid=25584) process 1 pid 76  len parquets (epochs): 38
# (pid=25582) process 0 pid 68  len parquets (epochs): 38
# (pid=25582) process 0 pid 69  len parquets (epochs): 38
# (pid=25584) process 1 pid 119  len parquets (epochs): 38
# (pid=25585) process 3 pid 106  len parquets (epochs): 38
# (pid=25582) process 0 pid 70  len parquets (epochs): 38
# (pid=25584) process 1 pid 120  len parquets (epochs): 38
# (pid=25585) exit merge process 3
# (pid=25584) process 1 pid 121  len parquets (epochs): 38
# (pid=25582) process 0 pid 71  len parquets (epochs): 38
# (pid=25584) process 1 pid 122  len parquets (epochs): 38
# (pid=25582) process
# (pid=25582) 0
# (pid=25582) pid 111  len parquets (epochs): 38
# (pid=25584) process 1 pid 79  len parquets (epochs): 38
# (pid=25582) process 0 pid 112  len parquets (epochs): 38
# (pid=25584) process 1 pid 44  len parquets (epochs): 38
# (pid=25582) process 0 pid 113  len parquets (epochs): 38
# (pid=25582) process 0 pid 114  len parquets (epochs): 38
# (pid=25582) exit merge process 0
# (pid=25584) process 1 pid 45  len parquets (epochs): 38
# (pid=25584) process 1 pid 80  len parquets (epochs): 38
# (pid=25584) process 1 pid 81  len parquets (epochs): 38
# (pid=25584) process 1 pid 82  len parquets (epochs): 38
# (pid=25584) exit merge process 1
# = = = = = TOTAL DATA ROUTING AND PERISITING TIME: 3880.218182325363 = = = = =
# finish nora data routing..

# %%
# num_process = 4
# problem_type = 2

# nora_hdfs = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/'
# qdtree_hdfs = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/'
# kdtree_hdfs = hdfs_base_path + 'KDTree/prob' + str(problem_type) + '/'

# # base path of Partition
# partition_base_path = '/home/centos/PartitionLayout/'

# nora_partition = partition_base_path + 'prob' + str(problem_type) + '_nora'
# qdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_qdtree'
# kdtree_partition = partition_base_path + 'prob' + str(problem_type) + '_kdtree'

# if __name__ == '__main__':
#     #batch_data_parallel(table_path, nora_partition, chunk_size, used_dims, nora_hdfs, num_dims, num_process, hdfs_private_ip)
#     #print('finish nora data routing..')
#     #batch_data_parallel(table_path, qdtree_partition, chunk_size, used_dims, qdtree_hdfs, num_dims, num_process, hdfs_private_ip)
#     #print('finish qdtree data routing..')
#     batch_data_parallel(table_path, kdtree_partition, chunk_size, used_dims, kdtree_hdfs, num_dims, num_process, hdfs_private_ip)
#     print('finish kdtree data routing..')

# %%
ray.shutdown()

# %%
# import pyarrow as pa
# import pyarrow.parquet as pq
# fs = pa.hdfs.connect()

# %%
# # read every parquet and dump it, see if it has a difference in query response time
# # use pyarrow !!!
# start_time = time.time()
# for i in range(421):
#     print("processing", i, "..")
#     pid = i
#     read_path = nora_hdfs + 'partition_' + str(pid)+'.parquet'
#     save_path = nora_hdfs + 'reorganized/partition_' + str(pid)+'.parquet'
#     adf = pq.read_table(read_path)
#     print('done read parquet from path')
#     fw = fs.open(save_path, 'wb')
#     print("start writing..")
#     pq.write_table(adf, fw)
#     fw.close()
# end_time = time.time()
# print('parquet merge time:',end_time-start_time)

# %%
# start_time = time.time()
# for i in range(68):
#     print("processing", i, "..")
#     pid = i
#     read_path = qdtree_hdfs + 'partition_' + str(pid)+'.parquet'
#     save_path = qdtree_hdfs + 'reorganized/partition_' + str(pid)+'.parquet'
#     adf = pq.read_table(read_path)
#     print('done read parquet from path')
#     fw = fs.open(save_path, 'wb')
#     print("start writing..")
#     pq.write_table(adf, fw)
#     fw.close()
# end_time = time.time()
# print('parquet merge time:',end_time-start_time)

# %%
# start_time = time.time()
# for i in range(512):
#     print("processing", i, "..")
#     pid = i
#     read_path = kdtree_hdfs + 'partition_' + str(pid)+'.parquet'
#     save_path = kdtree_hdfs + 'reorganized/partition_' + str(pid)+'.parquet'
#     adf = pq.read_table(read_path)
#     print('done read parquet from path')
#     fw = fs.open(save_path, 'wb')
#     print("start writing..")
#     pq.write_table(adf, fw)
#     fw.close()
# end_time = time.time()
# print('parquet merge time:',end_time-start_time)

# %%
import findspark
findspark.init() # this must be executed before the below import
from pyspark import SparkContext, SparkConf
from pyspark.sql import SQLContext
from pyspark.sql import SparkSession
from pyspark import SparkFiles
import ray
import time
import rtree
from rtree import index
import pandas as pd
import numpy as np
from numpy import genfromtxt
import threading
import pyarrow as pa
import pyarrow.parquet as pq
from partition_tree import PartitionTree

# %%
conf = SparkConf().setAll([("spark.executor.memory", "24g"),("spark.driver.memory","24g"),
                           ("spark.memory.offHeap.enabled",True),("spark.memory.offHeap.size","16g"),
                          ("spark.driver.maxResultSize", "16g")])

sc = SparkContext(conf=conf)
sqlContext = SQLContext(sc)
import os
os.environ['HADOOP_HOME'] = '/home/liupengju/hadoop'
os.environ['JAVA_HOME'] = '/home/liupengju/java/jdk1.8.0_281'
os.environ['ARROW_LIBHDFS_DIR'] = '/home/liupengju/hadoop/lib/native'
# Out:
# /home/liupengju/anaconda3/envs/torch/lib/python3.6/site-packages/pyspark/context.py:238: FutureWarning: Python 3.6 support is deprecated in Spark 3.2.
#   FutureWarning
# /home/liupengju/anaconda3/envs/torch/lib/python3.6/site-packages/pyspark/sql/context.py:79: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning

# %%
fs=pa.hdfs.connect(host='10.77.110.133', port=9001, user='liupengju')
# Out:
# /home/liupengju/anaconda3/envs/torch/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pyarrow.hdfs.connect is deprecated as of 2.0.0, please use pyarrow.fs.HadoopFileSystem instead.
#   """Entry point for launching an IPython kernel.

# %%
path='hdfs://10.77.110.133:9001/par_nora/NORA/prob2/scale100/epoch_0/partition_767.parquet'
adf=pa.Table.from_pandas(pd.DataFrame(np.array([[2,3,4]]), columns=['a1','a2','a3']))
with fs.open(path,'wb') as f:
    pq.write_table(adf, f)
