# %%
import findspark
findspark.init() # this must be executed before the below import

# %%
from pyspark.sql import SparkSession
import pyarrow as pa
import pyarrow.parquet as pq
spark = SparkSession \
    .builder \
    .master("local") \
    .appName("Python Spark SQL Execution") \
    .config("spark.executor.memory", "8g") \
    .config("spark.driver.memory","8g") \
    .config("spark.memory.offHeap.enabled",True) \
    .config("spark.memory.offHeap.size","8g") \
    .getOrCreate()

# %%
fs = pa.hdfs.connect(host='10.77.110.133', port=9001, user='liupengju')
import numpy as np
import time
import rtree
from rtree import index
from partition_tree import PartitionTree

# %%
def find_overlap_parquets(query, partition_index):
    '''
    find out all the overlap partition ids
    '''
    query_lower = [qr[0] for qr in query]
    query_upper = [qr[1] for qr in query]
    query_border = tuple(query_lower + query_upper)
    overlap_pids = list(partition_index.intersection(query_border))

    return overlap_pids


def transform_query_to_sql(query, used_dims, column_name_dict, hdfs_path, querytype=0, pids=None):
    sql = ''
    for i, dim in enumerate(used_dims):
        # if query[i][0] != -1:
        sql += column_name_dict[dim] + '>' + str(query[i]) + ' and '
        # if query[i][1] != -1:
        sql += column_name_dict[dim] + '<' + str(query[len(used_dims) + i]) + ' and '
    sql = sql[0:-4]  # remove the last 'and '
    
    if pids is not None and len(pids) != 0:
        pids = str(set(pids)).replace(" ", "")  # '{1,2,3}'
        hdfs_path = hdfs_path + '/partition_' + pids + ".parquet"

    if querytype == 0:
        sql = "SELECT * FROM parquet.`" + hdfs_path + "`WHERE " + sql
    elif querytype == 1:
        sql = "SELECT COUNT(*) FROM parquet.`" + hdfs_path + "`WHERE " + sql
    elif querytype == 2:
        sql = "SELECT variance(_c0) FROM parquet.`" + hdfs_path + "`WHERE " + sql
    elif querytype == 3:
        sql = "SELECT * FROM parquet.`" + hdfs_path + "`"
    elif querytype == 4:
        sql = "SELECT _c1,_c2,_c3 FROM parquet.`" + hdfs_path + "`"
    # else:
    # pids = str(set(pids)).replace(" ", "") # '{1,2,3}'
    # sql = "SELECT * FROM parquet.`" + hdfs_path + 'partition_' + pids + ".parquet` WHERE " + sql
    # sql = "SELECT COUNT(*) FROM parquet.`" + hdfs_path + 'partition_' + pids + ".parquet` WHERE " + sql
    # sql = "SELECT variance(_c0) FROM parquet.`" + hdfs_path + 'partition_' + pids + ".parquet` WHERE " + sql
    return sql


def query_with_parquets(query, used_dims, column_name_dict, hdfs_path, querytype=0, partition_tree=None,
                        print_execution_time=False):
    start_time = time.time()

    sql = None
    if partition_tree == None:
        sql = transform_query_to_sql(query, used_dims, column_name_dict, hdfs_path, querytype)
    else:
        pids = partition_tree.query_single(query)  # find_overlap_parquets(query, rtree_idx)
        sql = transform_query_to_sql(query, used_dims, column_name_dict, hdfs_path, querytype, pids)
        pre_sql = transform_query_to_sql(query, used_dims, column_name_dict, hdfs_path, 4, pids)
        # print(sql)
        print("pids:", pids)

    # print("generated sql:", sql)
    end_time_1 = time.time()
    # spark.sql(pre_sql).collect()
    query_result = spark.sql(sql).collect()

    # lazy_query = spark.sql(sql) # lazy execution
    # query_time = spark.time(spark.sql(sql).collect())  # there is no .time in pyspark

    end_time_2 = time.time()
    #     print("result size:", len(query_result))
    #     print("result content:", query_result)

    # 1. compute actual tuples from parquet file
    # pids = partition_tree.query_single(query)
    # pids = str(set(pids)).replace(" ", "")  # '{1,2,3}'
    # parquets_path = hdfs_path + '/partition_' + pids + ".parquet"
    # count_sql = "SELECT COUNT(*) FROM parquet.`" + parquets_path+"`"
    # actual_data_size=spark.sql(count_sql).collect()[0]['count(1)']
    # 2. compute actual tuples from parquet meta file
    pids = partition_tree.query_single(query)
    data_size_list1=[]
    data_size_list2=[]
    [data_size_list1.append(partition_tree.nid_node_dict[pid].node_size) for pid in pids]
    parquets_path=[hdfs_path + '/partition_' + str(pid) + ".parquet" for pid in pids]
    actual_data_size2=0
    for par_path in parquets_path:
        fw=fs.open(par_path,'rb')
        meta = pa.parquet.read_metadata(fw, memory_map=False).to_dict()
        actual_data_size2+=meta['num_rows']
        data_size_list2.append(meta['num_rows'])
        fw.close()
    query_translation_time = end_time_1 - start_time
    query_execution_time = end_time_2 - end_time_1
    print('query execution time: ', query_execution_time,' parquet size:',sum(data_size_list2))
    
    if print_execution_time:
        print('query translation time: ', query_translation_time)
        print('query execution time: ', query_execution_time)

    # return (query_result, query_translation_time, query_execution_time) # this takes too much memory
    return (query_translation_time, query_execution_time, len(query_result),actual_data_size2,sum(data_size_list1))

# %%
def load_query(path):
    query_set = np.genfromtxt(path, delimiter=' ')
    # query_set = query_set.reshape(len(query_set),-1,2)
    return query_set


def kdnode_2_border(kdnode):
    lower = [domain[0] for domain in kdnode[0]]
    upper = [domain[1] for domain in kdnode[0]]
    border = tuple(lower + upper)  # non interleave
    return border


def load_partitions_from_file(path):
    '''
    the loaded stretched_kdnodes: [num_dims, l1,l2,...,ln, u1,u2,...,un, size, id, pid, left_child,id, right_child_id]
    '''
    stretched_kdnodes = np.genfromtxt(path, delimiter=',')
    num_dims = int(stretched_kdnodes[0, 0])
    kdnodes = []
    for i in range(len(stretched_kdnodes)):
        domains = [[stretched_kdnodes[i, k + 1], stretched_kdnodes[i, 1 + num_dims + k]] for k in range(num_dims)]
        row = [domains]
        row.append(stretched_kdnodes[i, 2 * num_dims + 1])
        # to be compatible with qd-tree's partition, that do not have the last 4 attributes
        if len(stretched_kdnodes[i]) > 2 * num_dims + 2:
            row.append(stretched_kdnodes[i, -4])
            row.append(stretched_kdnodes[i, -3])
            row.append(stretched_kdnodes[i, -2])
            row.append(stretched_kdnodes[i, -1])
        kdnodes.append(row)
    return kdnodes


# def prepare_partition_index(partition_path):
#     partitions = load_partitions_from_file(partition_path)

#     p = index.Property()
#     p.leaf_capacity = 32
#     p.index_capacity = 32
#     p.NearMinimumOverlaoFactor = 16
#     p.fill_factor = 0.8
#     p.overwrite = True
#     pidx = index.Index(properties = p)

#     partition_index = index.Index(properties = p)
#     for i in range(len(partitions)):
#         partition_index.insert(i, kdnode_2_border(partitions[i]))

#     return partition_index

def batch_query(queryset, used_dims, column_name_dict, hdfs_path, querytype=0, partition_path=""):
    #     rtree_idx = None
    #     if use_rtree_idx:
    #         rtree_idx = prepare_partition_index(partition_path)

    partition_tree = PartitionTree(len(used_dims))  # newly added
    partition_tree.load_tree(partition_path)

    start_time = time.time()

    # add statistics result
    results = []
    count = 0
    for i in range(0, len(queryset)):
        result = query_with_parquets(queryset[i], used_dims, column_name_dict, hdfs_path, querytype, partition_tree)
        print('finish query#', count)
        count += 1
        results.append(result)
        # print("query:",queryset[i])
    #         if i == 0:
    #             break # just analysis top k queries
    end_time = time.time()

    result_size = 0
    actual_data_size=0
    thoery_data_size=0
    total_response_time=0
    for result in results:
        total_response_time+=result[1]
        result_size += result[2]
        actual_data_size+=result[3]
        thoery_data_size+=result[4]
    avg_result_size = int(result_size // len(queryset))
    avg_actual_data_size = int(actual_data_size // len(queryset))
    avg_thoery_data_size = int(thoery_data_size // len(queryset))
    print('average result size: ', avg_result_size)
    print('average actual data size: ', avg_actual_data_size)
    print('total query response time: ', total_response_time)
    print('average query response time: ', total_response_time / len(queryset))
    # print('average thoery data size: ', avg_thoery_data_size)

# %%
# ==== set environment parameters and generate dataset ====
scale_factor = 10
problem_type = 2
query_path = '/home/liupengju/pycharmProjects/NORA_JOIN_SIMULATION/NORA_experiments/queryset/'
## scale 50 and 10 / 100
training_set = np.genfromtxt(query_path+"prob"+str(problem_type)+"_"+str(scale_factor)+"_train"+".csv", delimiter=',')
used_dims = [1,2,3]
num_dims = 16
column_names = ['_c'+str(i) for i in range(num_dims)]
column_name_dict = {}
for i in range(num_dims):
    column_name_dict[i] = column_names[i]
# scale 100
# hdfs_path_nora = 'hdfs://10.77.110.133:9001/par_nora/NORA/prob'+str(problem_type)+'/scale100/merged/'
# hdfs_path_qdtree ='hdfs://10.77.110.133:9001/par_nora/QdTree/prob'+str(problem_type)+'/scale100/merged/'
# hdfs_path_paw ='hdfs://10.77.110.133:9001/par_nora/PAW/prob'+str(problem_type)+'/scale100/merged/'

# scale 50 and 10
hdfs_base_path = 'hdfs://10.77.110.133:9001/par_nora/'
hdfs_path_nora = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/merged/"
hdfs_path_qdtree = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/merged/"
hdfs_path_paw = hdfs_base_path + 'PAW/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/merged/"

# newly added
querytype = 2 # 0: SELECT *;  2: SELECT variance(_c0)
partition_base_path = '/home/liupengju/pycharmProjects/NORA_JOIN_SIMULATION/PartitionLayout/'
# scale 100
nora_partition_path = partition_base_path + 'prob' + str(problem_type) + '_nora_scale' + str(scale_factor)
qdtree_partition_path = partition_base_path + 'prob' + str(problem_type) + '_qdtree_scale' + str(scale_factor)
paw_partition_path = partition_base_path + 'prob' + str(problem_type) + '_paw_scale' + str(scale_factor)

# scale 50 and 10 / 100
# nora_partition_path = partition_base_path + 'prob' + str(problem_type) + '_nora_scale' + str(scale_factor)
# qdtree_partition_path = partition_base_path + 'prob' + str(problem_type) + '_qdtree_scale' + str(scale_factor)
# kdtree_partition_path = partition_base_path + 'prob' + str(problem_type) + '_kdtree_scale' + str(scale_factor)

# %%
def load_query(path):
    query_set = np.genfromtxt(path, delimiter=' ')
    # query_set = query_set.reshape(len(query_set),-1,2)
    return query_set


def kdnode_2_border(kdnode):
    lower = [domain[0] for domain in kdnode[0]]
    upper = [domain[1] for domain in kdnode[0]]
    border = tuple(lower + upper)  # non interleave
    return border


def load_partitions_from_file(path):
    '''
    the loaded stretched_kdnodes: [num_dims, l1,l2,...,ln, u1,u2,...,un, size, id, pid, left_child,id, right_child_id]
    '''
    stretched_kdnodes = np.genfromtxt(path, delimiter=',')
    num_dims = int(stretched_kdnodes[0, 0])
    kdnodes = []
    for i in range(len(stretched_kdnodes)):
        domains = [[stretched_kdnodes[i, k + 1], stretched_kdnodes[i, 1 + num_dims + k]] for k in range(num_dims)]
        row = [domains]
        row.append(stretched_kdnodes[i, 2 * num_dims + 1])
        # to be compatible with qd-tree's partition, that do not have the last 4 attributes
        if len(stretched_kdnodes[i]) > 2 * num_dims + 2:
            row.append(stretched_kdnodes[i, -4])
            row.append(stretched_kdnodes[i, -3])
            row.append(stretched_kdnodes[i, -2])
            row.append(stretched_kdnodes[i, -1])
        kdnodes.append(row)
    return kdnodes


# def prepare_partition_index(partition_path):
#     partitions = load_partitions_from_file(partition_path)

#     p = index.Property()
#     p.leaf_capacity = 32
#     p.index_capacity = 32
#     p.NearMinimumOverlaoFactor = 16
#     p.fill_factor = 0.8
#     p.overwrite = True
#     pidx = index.Index(properties = p)

#     partition_index = index.Index(properties = p)
#     for i in range(len(partitions)):
#         partition_index.insert(i, kdnode_2_border(partitions[i]))

#     return partition_index

def batch_query(queryset, used_dims, column_name_dict, hdfs_path, querytype=0, partition_path=""):
    #     rtree_idx = None
    #     if use_rtree_idx:
    #         rtree_idx = prepare_partition_index(partition_path)

    partition_tree = PartitionTree(len(used_dims))  # newly added
    partition_tree.load_tree(partition_path)

    start_time = time.time()

    # add statistics result
    results = []
    count = 0
    for i in range(0, len(queryset)):
        result = query_with_parquets(queryset[i], used_dims, column_name_dict, hdfs_path, querytype, partition_tree)
        print('finish query#', count)
        count += 1
        results.append(result)
        # print("query:",queryset[i])
    #         if i == 0:
    #             break # just analysis top k queries
    end_time = time.time()

    result_size = 0
    actual_data_size=0
    thoery_data_size=0
    total_response_time=0
    for result in results:
        total_response_time+=result[1]
        result_size += result[2]
        actual_data_size+=result[3]
        thoery_data_size+=result[4]
    avg_result_size = int(result_size // len(queryset))
    avg_actual_data_size = int(actual_data_size // len(queryset))
    avg_thoery_data_size = int(thoery_data_size // len(queryset))
    print('average result size: ', avg_result_size)
    print('average actual data size: ', avg_actual_data_size)
    print('total query response time: ', total_response_time)
    print('average query response time: ', total_response_time / len(queryset))
    # print('average thoery data size: ', avg_thoery_data_size)

# %%
# ==== set environment parameters and generate dataset ====
scale_factor = 10
problem_type = 2
query_path = '/home/liupengju/pycharmProjects/NORA_JOIN_SIMULATION/NORA_experiments/queryset/'
## scale 50 and 10 / 100
training_set = np.genfromtxt(query_path+"prob"+str(problem_type)+"_"+str(scale_factor)+"_train"+".csv", delimiter=',')
used_dims = [1,2,3]
num_dims = 16
column_names = ['_c'+str(i) for i in range(num_dims)]
column_name_dict = {}
for i in range(num_dims):
    column_name_dict[i] = column_names[i]
# scale 100
# hdfs_path_nora = 'hdfs://10.77.110.133:9001/par_nora/NORA/prob'+str(problem_type)+'/scale100/merged/'
# hdfs_path_qdtree ='hdfs://10.77.110.133:9001/par_nora/QdTree/prob'+str(problem_type)+'/scale100/merged/'
# hdfs_path_paw ='hdfs://10.77.110.133:9001/par_nora/PAW/prob'+str(problem_type)+'/scale100/merged/'

# scale 50 and 10
hdfs_base_path = 'hdfs://10.77.110.133:9001/par_nora/'
hdfs_path_nora = hdfs_base_path + 'NORA/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/merged/"
hdfs_path_qdtree = hdfs_base_path + 'QdTree/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/merged/"
hdfs_path_paw = hdfs_base_path + 'PAW/prob' + str(problem_type) + '/scale' + str(scale_factor) + "/merged/"

# newly added
querytype = 2 # 0: SELECT *;  2: SELECT variance(_c0)
partition_base_path = '/home/liupengju/pycharmProjects/NORA_JOIN_SIMULATION/PartitionLayout/'
# scale 100
nora_partition_path = partition_base_path + 'prob' + str(problem_type) + '_nora_scale' + str(scale_factor)
qdtree_partition_path = partition_base_path + 'prob' + str(problem_type) + '_qdtree_scale' + str(scale_factor)
paw_partition_path = partition_base_path + 'prob' + str(problem_type) + '_paw_scale' + str(scale_factor)

# scale 50 and 10 / 100
# nora_partition_path = partition_base_path + 'prob' + str(problem_type) + '_nora_scale' + str(scale_factor)
# qdtree_partition_path = partition_base_path + 'prob' + str(problem_type) + '_qdtree_scale' + str(scale_factor)
# kdtree_partition_path = partition_base_path + 'prob' + str(problem_type) + '_kdtree_scale' + str(scale_factor)

# %%
# Qd-Tree
batch_query(training_set, used_dims, column_name_dict, hdfs_path_qdtree, querytype, qdtree_partition_path)
# Out:
# pids: [371]
# query execution time:  0.9663307666778564  parquet size: 212842
# finish query# 0
# pids: [315, 308]
# query execution time:  0.1431427001953125  parquet size: 453248
# finish query# 1
# pids: [329, 403, 404]
# query execution time:  4.598523378372192  parquet size: 813850
# finish query# 2
# pids: [477, 478]
# query execution time:  0.14386534690856934  parquet size: 212865
# finish query# 3
# pids: [441, 442]
# query execution time:  0.13976740837097168  parquet size: 256178
# finish query# 4
# pids: [380, 220]
# query execution time:  1.2594013214111328  parquet size: 501172
# finish query# 5
# pids: [332]
# query execution time:  0.13219809532165527  parquet size: 171969
# finish query# 6
# pids: [298]
# query execution time:  0.12680602073669434  parquet size: 115541
# finish query# 7
# pids: [312, 437]
# query execution time:  0.31265807151794434  parquet size: 360642
# finish query# 8
# pids: [318, 215]
# query execution time:  1.7723743915557861  parquet size: 508386
# finish query# 9
# pids: [423]
# query execution time:  0.2897202968597412  parquet size: 160371
# finish query# 10
# pids: [333]
# query execution time:  0.6119740009307861  parquet size: 172566
# finish query# 11
# pids: [465, 250, 390, 466]
# query execution time:  0.16115689277648926  parquet size: 620305
# finish query# 12
# pids: [442]
# query execution time:  0.13238096237182617  parquet size: 105884
# finish query# 13
# pids: [203, 326]
# query execution time:  0.13985061645507812  parquet size: 281329
# finish query# 14
# pids: [254]
# query execution time:  0.13558268547058105  parquet size: 165677
# finish query# 15
# pids: [371, 462, 463]
# query execution time:  2.7528176307678223  parquet size: 477945
# finish query# 16
# pids: [356, 413]
# query execution time:  0.24966144561767578  parquet size: 245748
# finish query# 17
# pids: [430, 303]
# query execution time:  0.1738874912261963  parquet size: 326960
# finish query# 18
# pids: [240, 381, 382, 239]
# query execution time:  0.9795877933502197  parquet size: 486664
# finish query# 19
# pids: [458]
# query execution time:  0.3332536220550537  parquet size: 128015
# finish query# 20
# pids: [355, 356, 366, 451]
# query execution time:  0.9905185699462891  parquet size: 577019
# finish query# 21
# pids: [324]
# query execution time:  0.13016724586486816  parquet size: 183417
# finish query# 22
# pids: [458]
# query execution time:  0.7259621620178223  parquet size: 128015
# finish query# 23
# pids: [449, 436, 453]
# query execution time:  0.4884006977081299  parquet size: 427439
# finish query# 24
# pids: [173]
# query execution time:  0.13077878952026367  parquet size: 156499
# finish query# 25
# pids: [344, 239]
# query execution time:  0.2625298500061035  parquet size: 325402
# finish query# 26
# pids: [299, 419]
# query execution time:  0.8083407878875732  parquet size: 304446
# finish query# 27
# pids: [248, 247]
# query execution time:  0.12237119674682617  parquet size: 349796
# finish query# 28
# pids: [241, 460]
# query execution time:  1.5316059589385986  parquet size: 208698
# finish query# 29
# pids: [321, 322]
# query execution time:  1.3106234073638916  parquet size: 277950
# finish query# 30
# pids: [240]
# query execution time:  0.1309356689453125  parquet size: 108203
# finish query# 31
# pids: [328, 329, 330]
# query execution time:  2.776538372039795  parquet size: 497639
# finish query# 32
# pids: [424, 426]
# query execution time:  2.670203685760498  parquet size: 414396
# finish query# 33
# pids: [300, 301, 431, 432, 305]
# query execution time:  2.764831304550171  parquet size: 1076371
# finish query# 34
# pids: [250, 390]
# query execution time:  0.1264934539794922  parquet size: 326520
# finish query# 35
# pids: [322]
# query execution time:  0.4142301082611084  parquet size: 176191
# finish query# 36
# pids: [448, 332, 333, 334, 447]
# query execution time:  0.7759764194488525  parquet size: 772546
# finish query# 37
# pids: [250]
# query execution time:  0.12587356567382812  parquet size: 183937
# finish query# 38
# pids: [308, 437]
# query execution time:  0.13740134239196777  parquet size: 359350
# finish query# 39
# pids: [436, 437]
# query execution time:  0.13808703422546387  parquet size: 301278
# finish query# 40
# pids: [392, 183]
# query execution time:  0.8587813377380371  parquet size: 294414
# finish query# 41
# pids: [150]
# query execution time:  0.13556337356567383  parquet size: 139887
# finish query# 42
# pids: [408, 473, 162, 474]
# query execution time:  4.225001335144043  parquet size: 609991
# finish query# 43
# pids: [162]
# query execution time:  0.14489006996154785  parquet size: 130600
# finish query# 44
# pids: [435, 436]
# query execution time:  0.14158987998962402  parquet size: 271008
# finish query# 45
# pids: [427]
# query execution time:  2.759356737136841  parquet size: 279900
# finish query# 46
# pids: [328, 324, 327]
# query execution time:  0.15334033966064453  parquet size: 416368
# finish query# 47
# pids: [344, 381, 239]
# query execution time:  0.52555251121521  parquet size: 445659
# finish query# 48
# pids: [351, 359]
# query execution time:  1.1187262535095215  parquet size: 350860
# finish query# 49
# pids: [440, 439]
# query execution time:  0.3044886589050293  parquet size: 257889
# finish query# 50
# pids: [241]
# query execution time:  0.48656630516052246  parquet size: 105648
# finish query# 51
# pids: [434]
# query execution time:  0.14946341514587402  parquet size: 121401
# finish query# 52
# pids: [374]
# query execution time:  0.8064813613891602  parquet size: 162259
# finish query# 53
# pids: [347, 348]
# query execution time:  1.6101579666137695  parquet size: 282530
# finish query# 54
# pids: [195, 196]
# query execution time:  0.13565993309020996  parquet size: 273364
# finish query# 55
# pids: [447]
# query execution time:  0.5850253105163574  parquet size: 100450
# finish query# 56
# pids: [272]
# query execution time:  0.1214151382446289  parquet size: 341407
# finish query# 57
# pids: [442, 197]
# query execution time:  0.13292193412780762  parquet size: 288203
# finish query# 58
# pids: [418]
# query execution time:  0.12600350379943848  parquet size: 105856
# finish query# 59
# pids: [339, 334]
# query execution time:  0.9460365772247314  parquet size: 393654
# finish query# 60
# pids: [450]
# query execution time:  0.2968776226043701  parquet size: 106448
# finish query# 61
# pids: [352, 218]
# query execution time:  1.482558012008667  parquet size: 273917
# finish query# 62
# pids: [308, 437, 319]
# query execution time:  1.0029783248901367  parquet size: 561413
# finish query# 63
# pids: [308]
# query execution time:  1.3210673332214355  parquet size: 225855
# finish query# 64
# pids: [385, 386, 244]
# query execution time:  0.15197086334228516  parquet size: 560773
# finish query# 65
# pids: [321, 341, 342]
# query execution time:  0.7234671115875244  parquet size: 395861
# finish query# 66
# pids: [240]
# query execution time:  0.1289823055267334  parquet size: 108203
# finish query# 67
# pids: [367]
# query execution time:  1.1575400829315186  parquet size: 124770
# finish query# 68
# pids: [433, 434, 435]
# query execution time:  0.17441320419311523  parquet size: 332264
# finish query# 69
# pids: [385]
# query execution time:  0.15004897117614746  parquet size: 279359
# finish query# 70
# pids: [321, 196]
# query execution time:  0.17232251167297363  parquet size: 212760
# finish query# 71
# pids: [326, 325, 334]
# query execution time:  1.7505979537963867  parquet size: 493751
# finish query# 72
# pids: [426]
# query execution time:  0.3147304058074951  parquet size: 234427
# finish query# 73
# pids: [160, 410, 284]
# query execution time:  0.1687319278717041  parquet size: 518579
# finish query# 74
# pids: [466]
# query execution time:  0.12980151176452637  parquet size: 114710
# finish query# 75
# pids: [240, 125]
# query execution time:  0.24272513389587402  parquet size: 280967
# finish query# 76
# pids: [470]
# query execution time:  0.1473064422607422  parquet size: 221168
# finish query# 77
# pids: [284, 413, 279]
# query execution time:  0.411806583404541  parquet size: 813486
# finish query# 78
# pids: [437]
# query execution time:  0.7414116859436035  parquet size: 133495
# finish query# 79
# pids: [433, 434]
# query execution time:  0.17239737510681152  parquet size: 229039
# finish query# 80
# pids: [396]
# query execution time:  0.1739211082458496  parquet size: 221651
# finish query# 81
# pids: [413, 414]
# query execution time:  0.18132662773132324  parquet size: 278317
# finish query# 82
# pids: [374]
# query execution time:  0.3016188144683838  parquet size: 162259
# finish query# 83
# pids: [195, 196]
# query execution time:  0.1462688446044922  parquet size: 273364
# finish query# 84
# pids: [437, 319]
# query execution time:  0.13930892944335938  parquet size: 335558
# finish query# 85
# pids: [322, 446]
# query execution time:  0.6556024551391602  parquet size: 313218
# finish query# 86
# pids: [261]
# query execution time:  0.14235424995422363  parquet size: 136555
# finish query# 87
# pids: [398]
# query execution time:  0.21605801582336426  parquet size: 101132
# finish query# 88
# pids: [449, 450, 259, 184, 347]
# query execution time:  2.7253808975219727  parquet size: 1069873
# finish query# 89
# pids: [456]
# query execution time:  0.13469529151916504  parquet size: 107863
# finish query# 90
# pids: [326]
# query execution time:  0.1408548355102539  parquet size: 181592
# finish query# 91
# pids: [387, 388, 391, 392, 393, 248, 250]
# query execution time:  2.9422762393951416  parquet size: 1154816
# finish query# 92
# pids: [138, 251, 276]
# query execution time:  0.741408109664917  parquet size: 381722
# finish query# 93
# pids: [371]
# query execution time:  0.12605905532836914  parquet size: 212842
# finish query# 94
# pids: [418, 474, 475]
# query execution time:  2.8188915252685547  parquet size: 379098
# finish query# 95
# pids: [462]
# query execution time:  0.15482711791992188  parquet size: 119394
# finish query# 96
# pids: [424]
# query execution time:  0.1463489532470703  parquet size: 179969
# finish query# 97
# pids: [433, 434, 308]
# query execution time:  2.2626466751098633  parquet size: 454894
# finish query# 98
# pids: [400]
# query execution time:  0.1328754425048828  parquet size: 126376
# finish query# 99
# pids: [348]
# query execution time:  0.9651098251342773  parquet size: 115416
# finish query# 100
# pids: [348]
# query execution time:  0.5224030017852783  parquet size: 115416
# finish query# 101
# pids: [379]
# query execution time:  0.338651180267334  parquet size: 177194
# finish query# 102
# pids: [440, 308, 439]
# query execution time:  1.0826952457427979  parquet size: 483744
# finish query# 103
# pids: [449, 450, 347, 348, 350]
# query execution time:  0.15904951095581055  parquet size: 604504
# finish query# 104
# pids: [338]
# query execution time:  0.18778347969055176  parquet size: 109503
# finish query# 105
# pids: [325, 326, 199]
# query execution time:  2.2341015338897705  parquet size: 476094
# finish query# 106
# pids: [425, 426, 421, 422]
# query execution time:  1.7699415683746338  parquet size: 704783
# finish query# 107
# pids: [468]
# query execution time:  0.6555163860321045  parquet size: 134912
# finish query# 108
# pids: [352, 351, 215]
# query execution time:  0.151885986328125  parquet size: 557144
# finish query# 109
# pids: [363, 364]
# query execution time:  0.442795991897583  parquet size: 331821
# finish query# 110
# pids: [356]
# query execution time:  0.14385104179382324  parquet size: 137139
# finish query# 111
# pids: [195]
# query execution time:  0.13072586059570312  parquet size: 162363
# finish query# 112
# pids: [299, 300]
# query execution time:  1.6726632118225098  parquet size: 322437
# finish query# 113
# pids: [300]
# query execution time:  0.13409090042114258  parquet size: 207373
# finish query# 114
# pids: [125]
# query execution time:  0.23812389373779297  parquet size: 172764
# finish query# 115
# pids: [384]
# query execution time:  0.13077116012573242  parquet size: 147882
# finish query# 116
# pids: [316]
# query execution time:  0.5480856895446777  parquet size: 123945
# finish query# 117
# pids: [380]
# query execution time:  0.30784106254577637  parquet size: 204172
# finish query# 118
# pids: [338, 341]
# query execution time:  0.22906732559204102  parquet size: 257359
# finish query# 119
# pids: [240, 239]
# query execution time:  0.13474202156066895  parquet size: 246697
# finish query# 120
# pids: [477, 182]
# query execution time:  0.1426072120666504  parquet size: 269329
# finish query# 121
# pids: [459, 460]
# query execution time:  1.2548840045928955  parquet size: 253008
# finish query# 122
# pids: [203, 340]
# query execution time:  0.5608828067779541  parquet size: 201878
# finish query# 123
# pids: [345, 203, 204, 340]
# query execution time:  0.8194003105163574  parquet size: 497932
# finish query# 124
# pids: [448]
# query execution time:  0.3600773811340332  parquet size: 125689
# finish query# 125
# pids: [445]
# query execution time:  1.0182995796203613  parquet size: 126588
# finish query# 126
# pids: [422]
# query execution time:  0.11883258819580078  parquet size: 106871
# finish query# 127
# pids: [449, 450, 409, 410, 347]
# query execution time:  1.7096891403198242  parquet size: 698306
# finish query# 128
# pids: [444]
# query execution time:  0.2783687114715576  parquet size: 143593
# finish query# 129
# pids: [461, 373]
# query execution time:  0.14374852180480957  parquet size: 289133
# finish query# 130
# pids: [416, 412, 413]
# query execution time:  0.15999388694763184  parquet size: 417527
# finish query# 131
# pids: [244]
# query execution time:  0.130263090133667  parquet size: 145525
# finish query# 132
# pids: [196, 342]
# query execution time:  0.23684477806091309  parquet size: 257247
# finish query# 133
# pids: [440, 195]
# query execution time:  0.22079944610595703  parquet size: 270103
# finish query# 134
# pids: [329, 330, 204, 404, 479]
# query execution time:  1.9403719902038574  parquet size: 1110654
# finish query# 135
# pids: [204, 375]
# query execution time:  0.1472313404083252  parquet size: 350659
# finish query# 136
# pids: [378]
# query execution time:  0.563056468963623  parquet size: 207733
# finish query# 137
# pids: [300, 301, 430, 429]
# query execution time:  0.1658470630645752  parquet size: 631102
# finish query# 138
# pids: [250, 387]
# query execution time:  0.14055109024047852  parquet size: 286956
# finish query# 139
# pids: [333]
# query execution time:  0.13840055465698242  parquet size: 172566
# finish query# 140
# pids: [435, 436, 437, 438]
# query execution time:  0.1608409881591797  parquet size: 523335
# finish query# 141
# pids: [364]
# query execution time:  0.1388242244720459  parquet size: 110697
# finish query# 142
# pids: [421]
# query execution time:  0.13435912132263184  parquet size: 146865
# finish query# 143
# pids: [334]
# query execution time:  0.3495781421661377  parquet size: 201872
# finish query# 144
# pids: [324, 325]
# query execution time:  0.14020085334777832  parquet size: 293704
# finish query# 145
# pids: [129]
# query execution time:  0.14362430572509766  parquet size: 140848
# finish query# 146
# pids: [431]
# query execution time:  0.12909340858459473  parquet size: 177061
# finish query# 147
# pids: [160, 277]
# query execution time:  0.9541404247283936  parquet size: 333160
# finish query# 148
# pids: [436]
# query execution time:  0.12802815437316895  parquet size: 167783
# finish query# 149
# average result size:  44054
# average actual data size:  307778
# total query response time:  97.41702651977539
# average query response time:  0.6494468434651692

# %%
# PAW
batch_query(training_set, used_dims, column_name_dict, hdfs_path_paw, querytype, paw_partition_path)
# Out:
# pids: [491]
# query execution time:  0.9224138259887695  parquet size: 111089
# finish query# 0
# pids: [450, 461]
# query execution time:  0.13250017166137695  parquet size: 213663
# finish query# 1
# pids: [329, 411, 508, 507]
# query execution time:  4.47746467590332  parquet size: 813850
# finish query# 2
# pids: [523]
# query execution time:  0.13434457778930664  parquet size: 106523
# finish query# 3
# pids: [459, 460]
# query execution time:  0.13706469535827637  parquet size: 256178
# finish query# 4
# pids: [499, 359]
# query execution time:  1.2031636238098145  parquet size: 201400
# finish query# 5
# pids: [332]
# query execution time:  0.11739301681518555  parquet size: 171969
# finish query# 6
# pids: [297]
# query execution time:  0.11224889755249023  parquet size: 99698
# finish query# 7
# pids: [457, 453]
# query execution time:  0.259533166885376  parquet size: 234329
# finish query# 8
# pids: [352, 465, 351]
# query execution time:  1.927386999130249  parquet size: 343537
# finish query# 9
# pids: [433]
# query execution time:  0.2820017337799072  parquet size: 160371
# finish query# 10
# pids: [333]
# query execution time:  0.6327424049377441  parquet size: 172566
# finish query# 11
# pids: [250, 396, 501, 502]
# query execution time:  0.156174898147583  parquet size: 620305
# finish query# 12
# pids: [460]
# query execution time:  0.13494396209716797  parquet size: 105884
# finish query# 13
# pids: [203, 326]
# query execution time:  0.1488959789276123  parquet size: 281329
# finish query# 14
# pids: [254]
# query execution time:  0.1340467929840088  parquet size: 165677
# finish query# 15
# pids: [491, 494, 495]
# query execution time:  2.839484453201294  parquet size: 333691
# finish query# 16
# pids: [357, 423]
# query execution time:  0.2591583728790283  parquet size: 227972
# finish query# 17
# pids: [442, 303]
# query execution time:  0.14097809791564941  parquet size: 326960
# finish query# 18
# pids: [240, 385, 386, 239]
# query execution time:  0.8083014488220215  parquet size: 486664
# finish query# 19
# pids: [484]
# query execution time:  0.3736841678619385  parquet size: 128015
# finish query# 20
# pids: [477, 357, 358, 487]
# query execution time:  0.9915549755096436  parquet size: 441819
# finish query# 21
# pids: [324]
# query execution time:  0.12034249305725098  parquet size: 183417
# finish query# 22
# pids: [484]
# query execution time:  0.6370811462402344  parquet size: 128015
# finish query# 23
# pids: [475, 452, 479]
# query execution time:  0.4169173240661621  parquet size: 368314
# finish query# 24
# pids: [173]
# query execution time:  0.1321873664855957  parquet size: 156499
# finish query# 25
# pids: [344, 239]
# query execution time:  0.21948957443237305  parquet size: 325402
# finish query# 26
# pids: [299, 429]
# query execution time:  0.8821640014648438  parquet size: 304446
# finish query# 27
# pids: [248, 391]
# query execution time:  0.12622690200805664  parquet size: 217552
# finish query# 28
# pids: [241, 490]
# query execution time:  1.946488380432129  parquet size: 208698
# finish query# 29
# pids: [321, 322]
# query execution time:  1.5248093605041504  parquet size: 277950
# finish query# 30
# pids: [240]
# query execution time:  0.11556386947631836  parquet size: 108203
# finish query# 31
# pids: [328, 329, 330]
# query execution time:  3.1475915908813477  parquet size: 497639
# finish query# 32
# pids: [520, 434, 519]
# query execution time:  2.6130619049072266  parquet size: 414396
# finish query# 33
# pids: [521, 301, 439, 440, 445]
# query execution time:  2.636328935623169  parquet size: 542578
# finish query# 34
# pids: [250, 396]
# query execution time:  0.16568374633789062  parquet size: 326520
# finish query# 35
# pids: [322]
# query execution time:  0.3689243793487549  parquet size: 176191
# finish query# 36
# pids: [473, 332, 333, 471]
# query execution time:  0.6559791564941406  parquet size: 565505
# finish query# 37
# pids: [250]
# query execution time:  0.12525629997253418  parquet size: 183937
# finish query# 38
# pids: [449, 450, 453]
# query execution time:  0.14091229438781738  parquet size: 359350
# finish query# 39
# pids: [452, 453]
# query execution time:  0.13971638679504395  parquet size: 301278
# finish query# 40
# pids: [398, 183]
# query execution time:  0.837085485458374  parquet size: 294414
# finish query# 41
# pids: [150]
# query execution time:  0.12790846824645996  parquet size: 139887
# finish query# 42
# pids: [416, 513, 162, 514]
# query execution time:  4.1882405281066895  parquet size: 609991
# finish query# 43
# pids: [162]
# query execution time:  0.1276233196258545  parquet size: 130600
# finish query# 44
# pids: [451, 452]
# query execution time:  0.1356489658355713  parquet size: 271008
# finish query# 45
# pids: [437]
# query execution time:  2.7894880771636963  parquet size: 279900
# finish query# 46
# pids: [328, 324, 327]
# query execution time:  0.14536619186401367  parquet size: 416368
# finish query# 47
# pids: [344, 385, 239]
# query execution time:  0.5133254528045654  parquet size: 445659
# finish query# 48
# pids: [353, 363]
# query execution time:  1.2137081623077393  parquet size: 350860
# finish query# 49
# pids: [456]
# query execution time:  0.2579770088195801  parquet size: 129070
# finish query# 50
# pids: [241]
# query execution time:  0.36258769035339355  parquet size: 105648
# finish query# 51
# pids: [447]
# query execution time:  0.1118922233581543  parquet size: 113708
# finish query# 52
# pids: [378]
# query execution time:  0.7838943004608154  parquet size: 162259
# finish query# 53
# pids: [347, 348]
# query execution time:  1.4398066997528076  parquet size: 282530
# finish query# 54
# pids: [195]
# query execution time:  0.13771462440490723  parquet size: 116979
# finish query# 55
# pids: [473]
# query execution time:  0.6597769260406494  parquet size: 119489
# finish query# 56
# pids: [409]
# query execution time:  0.13515281677246094  parquet size: 171745
# finish query# 57
# pids: [460, 197]
# query execution time:  0.14130425453186035  parquet size: 288203
# finish query# 58
# pids: [428]
# query execution time:  0.13443279266357422  parquet size: 105856
# finish query# 59
# pids: [339, 471]
# query execution time:  0.9536881446838379  parquet size: 293263
# finish query# 60
# pids: [476]
# query execution time:  0.30113673210144043  parquet size: 106448
# finish query# 61
# pids: [218, 354]
# query execution time:  1.6090552806854248  parquet size: 273917
# finish query# 62
# pids: [450, 467, 453]
# query execution time:  0.8924863338470459  parquet size: 347844
# finish query# 63
# pids: [449, 450]
# query execution time:  1.3811001777648926  parquet size: 225855
# finish query# 64
# pids: [244, 389, 390]
# query execution time:  0.148881196975708  parquet size: 560773
# finish query# 65
# pids: [321, 341]
# query execution time:  0.5878355503082275  parquet size: 248788
# finish query# 66
# pids: [240]
# query execution time:  0.11261463165283203  parquet size: 108203
# finish query# 67
# pids: [371]
# query execution time:  1.0335719585418701  parquet size: 99098
# finish query# 68
# pids: [448, 451]
# query execution time:  0.13269996643066406  parquet size: 218556
# finish query# 69
# pids: [389]
# query execution time:  0.12078404426574707  parquet size: 279359
# finish query# 70
# pids: [321, 195]
# query execution time:  0.12776565551757812  parquet size: 218738
# finish query# 71
# pids: [472, 325, 326, 471]
# query execution time:  1.8498344421386719  parquet size: 493751
# finish query# 72
# pids: [519]
# query execution time:  0.2172226905822754  parquet size: 117792
# finish query# 73
# pids: [160, 420, 284]
# query execution time:  0.14907622337341309  parquet size: 518579
# finish query# 74
# pids: [502]
# query execution time:  0.13249659538269043  parquet size: 114710
# finish query# 75
# pids: [240, 125]
# query execution time:  0.26798009872436523  parquet size: 280967
# finish query# 76
# pids: [506]
# query execution time:  0.1374056339263916  parquet size: 221168
# finish query# 77
# pids: [511, 284, 423]
# query execution time:  0.25707244873046875  parquet size: 386288
# finish query# 78
# pids: [453]
# query execution time:  0.6249871253967285  parquet size: 133495
# finish query# 79
# pids: [448, 447]
# query execution time:  0.14208340644836426  parquet size: 229039
# finish query# 80
# pids: [402]
# query execution time:  0.1347367763519287  parquet size: 221651
# finish query# 81
# pids: [424, 423]
# query execution time:  0.16604185104370117  parquet size: 278317
# finish query# 82
# pids: [378]
# query execution time:  0.3271512985229492  parquet size: 162259
# finish query# 83
# pids: [195]
# query execution time:  0.1266329288482666  parquet size: 116979
# finish query# 84
# pids: [467, 453]
# query execution time:  0.1361675262451172  parquet size: 234057
# finish query# 85
# pids: [322, 470]
# query execution time:  0.6304664611816406  parquet size: 313218
# finish query# 86
# pids: [261]
# query execution time:  0.13599443435668945  parquet size: 136555
# finish query# 87
# pids: [404]
# query execution time:  0.21671152114868164  parquet size: 101132
# finish query# 88
# pids: [259, 475, 184, 347, 476]
# query execution time:  2.463934898376465  parquet size: 1069873
# finish query# 89
# pids: [482]
# query execution time:  0.12116122245788574  parquet size: 107863
# finish query# 90
# pids: [326]
# query execution time:  0.11235833168029785  parquet size: 181592
# finish query# 91
# pids: [393, 394, 397, 398, 399, 248, 250]
# query execution time:  3.0501413345336914  parquet size: 1154816
# finish query# 92
# pids: [137, 275, 251]
# query execution time:  0.7097256183624268  parquet size: 301656
# finish query# 93
# pids: [491]
# query execution time:  0.13253235816955566  parquet size: 111089
# finish query# 94
# pids: [514, 515, 428]
# query execution time:  2.6593852043151855  parquet size: 379098
# finish query# 95
# pids: [494]
# query execution time:  0.13090229034423828  parquet size: 119394
# finish query# 96
# pids: [434]
# query execution time:  0.12397909164428711  parquet size: 179969
# finish query# 97
# pids: [448, 449, 447]
# query execution time:  2.0337960720062256  parquet size: 341107
# finish query# 98
# pids: [406]
# query execution time:  0.15665411949157715  parquet size: 126376
# finish query# 99
# pids: [348]
# query execution time:  0.9419972896575928  parquet size: 115416
# finish query# 100
# pids: [348]
# query execution time:  0.5136408805847168  parquet size: 115416
# finish query# 101
# pids: [383]
# query execution time:  0.25511908531188965  parquet size: 177194
# finish query# 102
# pids: [456, 449, 450, 455]
# query execution time:  0.9496495723724365  parquet size: 483744
# finish query# 103
# pids: [475, 348, 347, 476, 350]
# query execution time:  0.14903020858764648  parquet size: 604504
# finish query# 104
# pids: [338]
# query execution time:  0.1388695240020752  parquet size: 109503
# finish query# 105
# pids: [325, 326, 199]
# query execution time:  1.9791016578674316  parquet size: 476094
# finish query# 106
# pids: [432, 431, 517, 519]
# query execution time:  1.7041802406311035  parquet size: 479358
# finish query# 107
# pids: [503]
# query execution time:  0.6383841037750244  parquet size: 101193
# finish query# 108
# pids: [352, 353, 354]
# query execution time:  0.13853836059570312  parquet size: 432718
# finish query# 109
# pids: [368, 485]
# query execution time:  0.3353705406188965  parquet size: 211817
# finish query# 110
# pids: [357]
# query execution time:  0.12195754051208496  parquet size: 119363
# finish query# 111
# pids: [195]
# query execution time:  0.12505531311035156  parquet size: 116979
# finish query# 112
# pids: [299, 439]
# query execution time:  1.5324809551239014  parquet size: 218458
# finish query# 113
# pids: [440, 439]
# query execution time:  0.13474297523498535  parquet size: 207373
# finish query# 114
# pids: [125]
# query execution time:  0.25420284271240234  parquet size: 172764
# finish query# 115
# pids: [388]
# query execution time:  0.13084721565246582  parquet size: 126518
# finish query# 116
# pids: [316]
# query execution time:  0.4452016353607178  parquet size: 123945
# finish query# 117
# pids: [499, 500]
# query execution time:  0.34194278717041016  parquet size: 204172
# finish query# 118
# pids: [338, 342]
# query execution time:  0.25211381912231445  parquet size: 256576
# finish query# 119
# pids: [240, 239]
# query execution time:  0.13307952880859375  parquet size: 246697
# finish query# 120
# pids: [523, 182]
# query execution time:  0.163041353225708  parquet size: 270657
# finish query# 121
# pids: [489, 490]
# query execution time:  1.4714796543121338  parquet size: 253008
# finish query# 122
# pids: [203, 340]
# query execution time:  0.5236728191375732  parquet size: 201878
# finish query# 123
# pids: [345, 203, 204, 340]
# query execution time:  0.8715147972106934  parquet size: 477801
# finish query# 124
# pids: [473]
# query execution time:  0.4518287181854248  parquet size: 119489
# finish query# 125
# pids: [469]
# query execution time:  1.1325984001159668  parquet size: 126588
# finish query# 126
# pids: [432]
# query execution time:  0.16499686241149902  parquet size: 106871
# finish query# 127
# pids: [419, 420, 475, 347, 476]
# query execution time:  1.9503600597381592  parquet size: 698306
# finish query# 128
# pids: [464]
# query execution time:  0.3232088088989258  parquet size: 143593
# finish query# 129
# pids: [377, 493]
# query execution time:  0.14166760444641113  parquet size: 289133
# finish query# 130
# pids: [426, 422, 423]
# query execution time:  0.1475963592529297  parquet size: 413037
# finish query# 131
# pids: [244]
# query execution time:  0.13957548141479492  parquet size: 145525
# finish query# 132
# pids: [195, 341]
# query execution time:  0.25315213203430176  parquet size: 264008
# finish query# 133
# pids: [456, 195]
# query execution time:  0.2597320079803467  parquet size: 246049
# finish query# 134
# pids: [329, 330, 204, 525, 508]
# query execution time:  2.140611171722412  parquet size: 966954
# finish query# 135
# pids: [379, 204]
# query execution time:  0.1560523509979248  parquet size: 350659
# finish query# 136
# pids: [497]
# query execution time:  0.5323185920715332  parquet size: 101145
# finish query# 137
# pids: [440, 441, 442, 301]
# query execution time:  0.15251469612121582  parquet size: 527708
# finish query# 138
# pids: [393, 250]
# query execution time:  0.13546013832092285  parquet size: 286956
# finish query# 139
# pids: [333]
# query execution time:  0.13341188430786133  parquet size: 172566
# finish query# 140
# pids: [451, 452, 453, 454]
# query execution time:  0.1595594882965088  parquet size: 523335
# finish query# 141
# pids: [368]
# query execution time:  0.14879870414733887  parquet size: 110697
# finish query# 142
# pids: [431]
# query execution time:  0.13277959823608398  parquet size: 146865
# finish query# 143
# pids: [472, 471]
# query execution time:  0.3496575355529785  parquet size: 201872
# finish query# 144
# pids: [324, 325]
# query execution time:  0.13729548454284668  parquet size: 293704
# finish query# 145
# pids: [129]
# query execution time:  0.13533473014831543  parquet size: 99117
# finish query# 146
# pids: [445]
# query execution time:  0.12543392181396484  parquet size: 129458
# finish query# 147
# pids: [160, 277]
# query execution time:  1.0602264404296875  parquet size: 333160
# finish query# 148
# pids: [452]
# query execution time:  0.11740279197692871  parquet size: 167783
# finish query# 149
# average result size:  44054
# average actual data size:  270432
# total query response time:  96.25818037986755
# average query response time:  0.6417212025324504

# %%
# NORA
batch_query(training_set, used_dims, column_name_dict, hdfs_path_nora, querytype, nora_partition_path)
# Out:
# pids: [501]
# query execution time:  0.888373613357544  parquet size: 114315
# finish query# 0
# pids: [471]
# query execution time:  0.1459202766418457  parquet size: 99876
# finish query# 1
# pids: [536, 743, 535]
# query execution time:  5.798771858215332  parquet size: 463526
# finish query# 2
# pids: [473]
# query execution time:  0.14585280418395996  parquet size: 101521
# finish query# 3
# pids: [470]
# query execution time:  0.13528180122375488  parquet size: 109233
# finish query# 4
# pids: [373]
# query execution time:  1.220435380935669  parquet size: 111687
# finish query# 5
# pids: [344]
# query execution time:  0.11366605758666992  parquet size: 160490
# finish query# 6
# pids: [303]
# query execution time:  0.12602567672729492  parquet size: 113698
# finish query# 7
# pids: [467]
# query execution time:  0.2734949588775635  parquet size: 100834
# finish query# 8
# pids: [529, 363]
# query execution time:  1.914266586303711  parquet size: 223644
# finish query# 9
# pids: [451]
# query execution time:  0.2988474369049072  parquet size: 164322
# finish query# 10
# pids: [345]
# query execution time:  0.6881413459777832  parquet size: 149668
# finish query# 11
# pids: [414]
# query execution time:  0.15085697174072266  parquet size: 120976
# finish query# 12
# pids: [470]
# query execution time:  0.11663055419921875  parquet size: 109233
# finish query# 13
# pids: [481]
# query execution time:  0.12882161140441895  parquet size: 151669
# finish query# 14
# pids: [256]
# query execution time:  0.13268041610717773  parquet size: 112840
# finish query# 15
# pids: [504, 505]
# query execution time:  2.651536226272583  parquet size: 261627
# finish query# 16
# pids: [371]
# query execution time:  0.2570481300354004  parquet size: 104797
# finish query# 17
# pids: [308]
# query execution time:  0.1361539363861084  parquet size: 110239
# finish query# 18
# pids: [399]
# query execution time:  0.9457807540893555  parquet size: 111164
# finish query# 19
# pids: [497]
# query execution time:  0.36296868324279785  parquet size: 158126
# finish query# 20
# pids: [384]
# query execution time:  1.1628108024597168  parquet size: 134553
# finish query# 21
# pids: [198]
# query execution time:  0.1446220874786377  parquet size: 151766
# finish query# 22
# pids: [532]
# query execution time:  0.7124507427215576  parquet size: 118802
# finish query# 23
# pids: [495]
# query execution time:  0.4095795154571533  parquet size: 99776
# finish query# 24
# pids: [303]
# query execution time:  0.12150788307189941  parquet size: 113698
# finish query# 25
# pids: [489]
# query execution time:  0.2322843074798584  parquet size: 137695
# finish query# 26
# pids: [523]
# query execution time:  0.8116059303283691  parquet size: 120143
# finish query# 27
# pids: [250, 407]
# query execution time:  0.14058494567871094  parquet size: 203010
# finish query# 28
# pids: [241, 500]
# query execution time:  1.658567190170288  parquet size: 208698
# finish query# 29
# pids: [331]
# query execution time:  1.337555170059204  parquet size: 186229
# finish query# 30
# pids: [399]
# query execution time:  0.2150132656097412  parquet size: 111164
# finish query# 31
# pids: [338, 340]
# query execution time:  2.7267050743103027  parquet size: 351175
# finish query# 32
# pids: [453, 527]
# query execution time:  2.7747910022735596  parquet size: 302994
# finish query# 33
# pids: [456, 306]
# query execution time:  2.645368814468384  parquet size: 278525
# finish query# 34
# pids: [414]
# query execution time:  0.11943864822387695  parquet size: 120976
# finish query# 35
# pids: [332]
# query execution time:  0.40020060539245605  parquet size: 176191
# finish query# 36
# pids: [483]
# query execution time:  0.6452548503875732  parquet size: 182044
# finish query# 37
# pids: [252]
# query execution time:  0.12818479537963867  parquet size: 146678
# finish query# 38
# pids: [459]
# query execution time:  0.1175539493560791  parquet size: 181979
# finish query# 39
# pids: [461, 463]
# query execution time:  0.1340775489807129  parquet size: 252883
# finish query# 40
# pids: [416]
# query execution time:  0.8584105968475342  parquet size: 100597
# finish query# 41
# pids: [271]
# query execution time:  0.13849854469299316  parquet size: 100134
# finish query# 42
# pids: [520, 435, 519]
# query execution time:  4.388411045074463  parquet size: 473945
# finish query# 43
# pids: [286]
# query execution time:  0.13418030738830566  parquet size: 128585
# finish query# 44
# pids: [462]
# query execution time:  0.13589715957641602  parquet size: 172725
# finish query# 45
# pids: [708]
# query execution time:  3.0862936973571777  parquet size: 279900
# finish query# 46
# pids: [337]
# query execution time:  0.13174653053283691  parquet size: 101569
# finish query# 47
# pids: [489]
# query execution time:  0.48848462104797363  parquet size: 137695
# finish query# 48
# pids: [377]
# query execution time:  1.4098987579345703  parquet size: 194763
# finish query# 49
# pids: [466]
# query execution time:  0.24027490615844727  parquet size: 129070
# finish query# 50
# pids: [241]
# query execution time:  0.42989516258239746  parquet size: 105648
# finish query# 51
# pids: [457]
# query execution time:  0.14670109748840332  parquet size: 135408
# finish query# 52
# pids: [391]
# query execution time:  0.8564300537109375  parquet size: 158691
# finish query# 53
# pids: [360, 359]
# query execution time:  1.777099370956421  parquet size: 318223
# finish query# 54
# pids: [195]
# query execution time:  0.14022159576416016  parquet size: 120890
# finish query# 55
# pids: [485]
# query execution time:  0.586064338684082  parquet size: 119489
# finish query# 56
# pids: [513]
# query execution time:  0.13509011268615723  parquet size: 110488
# finish query# 57
# pids: [470]
# query execution time:  0.12888622283935547  parquet size: 109233
# finish query# 58
# pids: [446]
# query execution time:  0.12444758415222168  parquet size: 101440
# finish query# 59
# pids: [483]
# query execution time:  0.934401273727417  parquet size: 182044
# finish query# 60
# pids: [361]
# query execution time:  0.2625617980957031  parquet size: 136016
# finish query# 61
# pids: [370]
# query execution time:  1.3730695247650146  parquet size: 148369
# finish query# 62
# pids: [477]
# query execution time:  0.8298361301422119  parquet size: 101319
# finish query# 63
# pids: [459, 460]
# query execution time:  1.5770025253295898  parquet size: 290264
# finish query# 64
# pids: [244]
# query execution time:  0.1409013271331787  parquet size: 102591
# finish query# 65
# pids: [331]
# query execution time:  0.5680394172668457  parquet size: 186229
# finish query# 66
# pids: [399]
# query execution time:  0.21707367897033691  parquet size: 111164
# finish query# 67
# pids: [385]
# query execution time:  1.183321475982666  parquet size: 172873
# finish query# 68
# pids: [458]
# query execution time:  0.12995362281799316  parquet size: 108341
# finish query# 69
# pids: [244]
# query execution time:  0.1255936622619629  parquet size: 102591
# finish query# 70
# pids: [331]
# query execution time:  0.24420809745788574  parquet size: 186229
# finish query# 71
# pids: [483, 484]
# query execution time:  1.8046166896820068  parquet size: 299294
# finish query# 72
# pids: [453]
# query execution time:  0.190293550491333  parquet size: 115519
# finish query# 73
# pids: [287]
# query execution time:  0.13789629936218262  parquet size: 105857
# finish query# 74
# pids: [411]
# query execution time:  0.11817646026611328  parquet size: 98245
# finish query# 75
# pids: [240]
# query execution time:  0.1291201114654541  parquet size: 126977
# finish query# 76
# pids: [737]
# query execution time:  0.13953900337219238  parquet size: 109491
# finish query# 77
# pids: [517]
# query execution time:  0.27091407775878906  parquet size: 101980
# finish query# 78
# pids: [463]
# query execution time:  0.7766871452331543  parquet size: 145841
# finish query# 79
# pids: [457]
# query execution time:  0.13123035430908203  parquet size: 135408
# finish query# 80
# pids: [677, 678]
# query execution time:  0.14691972732543945  parquet size: 275645
# finish query# 81
# pids: [439]
# query execution time:  0.13022446632385254  parquet size: 114746
# finish query# 82
# pids: [391]
# query execution time:  0.32820820808410645  parquet size: 158691
# finish query# 83
# pids: [195]
# query execution time:  0.1305856704711914  parquet size: 120890
# finish query# 84
# pids: [477]
# query execution time:  0.12574195861816406  parquet size: 101319
# finish query# 85
# pids: [480]
# query execution time:  0.6745150089263916  parquet size: 137027
# finish query# 86
# pids: [421]
# query execution time:  0.13528132438659668  parquet size: 105480
# finish query# 87
# pids: [426]
# query execution time:  0.22098660469055176  parquet size: 101132
# finish query# 88
# pids: [571]
# query execution time:  2.4073450565338135  parquet size: 235525
# finish query# 89
# pids: [531]
# query execution time:  0.22022700309753418  parquet size: 112112
# finish query# 90
# pids: [482]
# query execution time:  0.11408472061157227  parquet size: 104810
# finish query# 91
# pids: [417, 257]
# query execution time:  2.9233503341674805  parquet size: 342552
# finish query# 92
# pids: [137]
# query execution time:  0.6751203536987305  parquet size: 159485
# finish query# 93
# pids: [501]
# query execution time:  0.11913228034973145  parquet size: 114315
# finish query# 94
# pids: [520, 522, 446]
# query execution time:  2.740554094314575  parquet size: 352723
# finish query# 95
# pids: [504]
# query execution time:  0.1279451847076416  parquet size: 163045
# finish query# 96
# pids: [527]
# query execution time:  0.11668777465820312  parquet size: 187475
# finish query# 97
# pids: [457, 459]
# query execution time:  1.830519199371338  parquet size: 317387
# finish query# 98
# pids: [424]
# query execution time:  0.1454460620880127  parquet size: 126376
# finish query# 99
# pids: [359]
# query execution time:  1.0102462768554688  parquet size: 147525
# finish query# 100
# pids: [367]
# query execution time:  0.5193114280700684  parquet size: 133533
# finish query# 101
# pids: [509]
# query execution time:  0.23046207427978516  parquet size: 109777
# finish query# 102
# pids: [459]
# query execution time:  0.9023938179016113  parquet size: 181979
# finish query# 103
# pids: [361]
# query execution time:  0.13022398948669434  parquet size: 136016
# finish query# 104
# pids: [350]
# query execution time:  0.11754536628723145  parquet size: 109503
# finish query# 105
# pids: [481, 482]
# query execution time:  1.8004941940307617  parquet size: 256479
# finish query# 106
# pids: [453, 525]
# query execution time:  1.7179417610168457  parquet size: 223349
# finish query# 107
# pids: [425]
# query execution time:  0.6415526866912842  parquet size: 134912
# finish query# 108
# pids: [365]
# query execution time:  0.14298152923583984  parquet size: 105486
# finish query# 109
# pids: [381]
# query execution time:  0.3411140441894531  parquet size: 133630
# finish query# 110
# pids: [371]
# query execution time:  0.1354079246520996  parquet size: 104797
# finish query# 111
# pids: [195]
# query execution time:  0.13121438026428223  parquet size: 120890
# finish query# 112
# pids: [456, 455]
# query execution time:  1.6776185035705566  parquet size: 266886
# finish query# 113
# pids: [306]
# query execution time:  0.12298417091369629  parquet size: 125650
# finish query# 114
# pids: [125]
# query execution time:  0.2606470584869385  parquet size: 172764
# finish query# 115
# pids: [401]
# query execution time:  0.1313157081604004  parquet size: 135416
# finish query# 116
# pids: [326]
# query execution time:  0.5282995700836182  parquet size: 123945
# finish query# 117
# pids: [510]
# query execution time:  0.2851219177246094  parquet size: 109722
# finish query# 118
# pids: [357]
# query execution time:  0.22935700416564941  parquet size: 102277
# finish query# 119
# pids: [240]
# query execution time:  0.13438010215759277  parquet size: 126977
# finish query# 120
# pids: [313]
# query execution time:  0.1428525447845459  parquet size: 100704
# finish query# 121
# pids: [499]
# query execution time:  1.275721549987793  parquet size: 165567
# finish query# 122
# pids: [357]
# query execution time:  0.5430629253387451  parquet size: 102277
# finish query# 123
# pids: [355]
# query execution time:  0.7864632606506348  parquet size: 100570
# finish query# 124
# pids: [485]
# query execution time:  0.3930947780609131  parquet size: 119489
# finish query# 125
# pids: [479]
# query execution time:  1.227463960647583  parquet size: 129121
# finish query# 126
# pids: [450]
# query execution time:  0.13296031951904297  parquet size: 134572
# finish query# 127
# pids: [283]
# query execution time:  1.8727576732635498  parquet size: 197996
# finish query# 128
# pids: [475]
# query execution time:  0.25324487686157227  parquet size: 101040
# finish query# 129
# pids: [391]
# query execution time:  0.12680268287658691  parquet size: 158691
# finish query# 130
# pids: [441]
# query execution time:  0.12902569770812988  parquet size: 138749
# finish query# 131
# pids: [128]
# query execution time:  0.14031338691711426  parquet size: 117021
# finish query# 132
# pids: [195]
# query execution time:  0.13784170150756836  parquet size: 120890
# finish query# 133
# pids: [195]
# query execution time:  0.1283247470855713  parquet size: 120890
# finish query# 134
# pids: [537]
# query execution time:  2.1142325401306152  parquet size: 171452
# finish query# 135
# pids: [341]
# query execution time:  0.14415240287780762  parquet size: 108947
# finish query# 136
# pids: [507]
# query execution time:  0.5456488132476807  parquet size: 100940
# finish query# 137
# pids: [308]
# query execution time:  0.13608264923095703  parquet size: 110239
# finish query# 138
# pids: [247]
# query execution time:  0.13600754737854004  parquet size: 100367
# finish query# 139
# pids: [345]
# query execution time:  0.14529013633728027  parquet size: 149668
# finish query# 140
# pids: [461]
# query execution time:  0.14254546165466309  parquet size: 107042
# finish query# 141
# pids: [381]
# query execution time:  0.13255906105041504  parquet size: 133630
# finish query# 142
# pids: [449]
# query execution time:  0.14243054389953613  parquet size: 163009
# finish query# 143
# pids: [483]
# query execution time:  0.35391688346862793  parquet size: 182044
# finish query# 144
# pids: [335]
# query execution time:  0.1483454704284668  parquet size: 134396
# finish query# 145
# pids: [511]
# query execution time:  0.14199352264404297  parquet size: 109265
# finish query# 146
# pids: [715]
# query execution time:  0.15459918975830078  parquet size: 102325
# finish query# 147
# pids: [279]
# query execution time:  0.9655518531799316  parquet size: 149917
# finish query# 148
# pids: [462]
# query execution time:  0.12226319313049316  parquet size: 172725
# finish query# 149
# average result size:  44260
# average actual data size:  153955
# total query response time:  97.21011805534363
# average query response time:  0.6480674537022909

# %%
# check number of row groups
# import pyarrow as pa
# fs = pa.fs.HadoopFileSystem('192.168.6.62', port=9000, user='hdfs', replication=1)
# path1 = 'hdfs://192.168.6.62:9000/user/cloudray/NORA/prob1/merged/partition_94.parquet'
# path2 = 'hdfs://192.168.6.62:9000/user/cloudray/KDTree/prob1/merged/partition_98.parquet'
# fw1 = fs.open_input_file(path1)
# meta1 = pa.parquet.read_metadata(fw1, memory_map=False)
# print(meta1)
# print(meta1.row_group(0))
# fw1.close()
#
# fw2 = fs.open_input_file(path2)
# meta2 = pa.parquet.read_metadata(fw2, memory_map=False)
# print(meta2)
# print(meta2.row_group(0))
# fw2.close()
